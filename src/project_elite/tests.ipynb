# %%
import json

# %%
test_path = "C:\\Users\\jziac\\OneDrive\\Documents\\programovani\\projekty\\elite\\data\\test_data\\"

# %%
import src.project_elite.scraper.league.league as league_scraper
ls_o = league_scraper.LeagueScrapper("https://www.eliteprospects.com/league/czechia")
league_data = ls_o.get_league_data()
league_data
# Out:
# c:\Users\jziac\miniforge3\envs\p-env\lib\site-packages\scrapy\selector\unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
# https://www.eliteprospects.com/league/czechia/standings/2022-2023
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# []
# 1
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2021-2022
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# []
# 1
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][15]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2020-2021
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# []
# 1
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2018-2019
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Play-out', 'Qualification']
# 3
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2017-2018
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Play-out', 'Qualification']
# 3
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2016-2017
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Playout', 'Qualification']
# 3
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2015-2016
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Playout', 'Qualification']
# 3
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2014-2015
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Playout', 'Relegation']
# 3
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2013-2014
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Playout', 'Relegation']
# 3
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2012-2013
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Play-out', 'Relegation']
# 3
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][3]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2011-2012
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Play-out']
# 2
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2010-2011
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Play-out']
# 2
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2009-2010
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Play-out']
# 2
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2008-2009
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Play-out']
# 2
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2007-2008
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# ['Play-out']
# 2
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][2]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2006-2007
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# []
# 1
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2005-2006
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# []
# 1
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2004-2005
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# []
# 1
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][5]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][6]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][7]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][8]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][9]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][10]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][11]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][12]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][13]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][14]/td[@class='team']//a/@href
# https://www.eliteprospects.com/league/czechia/standings/2003-2004
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1]
# []
# 1
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][1]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][2]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][3]/td[@class='team']//a/@href
# //table[@class = 'table standings table-sortable']//tbody[count(./tr/*)>1][1]/tr[not(@class = 'title')][4]/td[@class='team']//a/@href
# ...
#      'tp': '62',
#      'postseason': 'Final loss',
#      '772': 'https://www.eliteprospects.com/team/772/hc-vitkovice'},
#     '4.': {'team': 'HC Třinec',
#      'gp': '52',
#      'w': '23',
#      't': '10',
#      'l': '19',
#      'otw': '-',
#      'otl': '-',
#      'gf': '175',
#      'ga': '152',
#      'plus_minus': '23',
#      'tp': '56',
#      'postseason': 'Quarterfinal loss',
#      '161': 'https://www.eliteprospects.com/team/161/hc-t%C5%99inec'},
#     '5.': {'team': 'HC Pardubice',
#      'gp': '52',
#      'w': '25',
#      't': '5',
#      'l': '22',
#      'otw': '-',
#      'otl': '-',
#      'gf': '170',
#      'ga': '164',
#      'plus_minus': '6',
#      'tp': '55',
#      'postseason': 'Semifinal loss',
#      '159': 'https://www.eliteprospects.com/team/159/hc-pardubice'},
#     '6.': {'team': 'HC Kladno',
#      'gp': '52',
#      'w': '21',
#      't': '12',
#      'l': '19',
#      'otw': '-',
#      'otl': '-',
#      'gf': '132',
#      'ga': '152',
#      'plus_minus': '-20',
#      'tp': '54',
#      'postseason': 'Quarterfinal loss',
#      '646': 'https://www.eliteprospects.com/team/646/hc-kladno'},
#     '7.': {'team': 'HC České Budějovice',
#      'gp': '52',
#      'w': '20',
#      't': '12',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '149',
#      'ga': '145',
#      'plus_minus': '4',
#      'tp': '52',
#      'postseason': 'Quarterfinal loss',
#      '154': 'https://www.eliteprospects.com/team/154/hc-%C4%8Ceske-bud%C4%9Bjovice'},
#     '8.': {'team': 'HC Slavia Praha',
#      'gp': '52',
#      'w': '21',
#      't': '10',
#      'l': '21',
#      'otw': '-',
#      'otl': '-',
#      'gf': '166',
#      'ga': '167',
#      'plus_minus': '-1',
#      'tp': '52',
#      'postseason': 'Quarterfinal loss',
#      '162': 'https://www.eliteprospects.com/team/162/hc-slavia-praha'},
#     '9.': {'team': 'HC Chemopetrol',
#      'gp': '52',
#      'w': '20',
#      't': '12',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '171',
#      'ga': '185',
#      'plus_minus': '-14',
#      'tp': '52',
#      'postseason': 'Did not make playoffs',
#      '155': 'https://www.eliteprospects.com/team/155/hc-chemopetrol'},
#     '10.': {'team': 'AC Zlín',
#      'gp': '52',
#      'w': '22',
#      't': '6',
#      'l': '24',
#      'otw': '-',
#      'otl': '-',
#      'gf': '179',
#      'ga': '179',
#      'plus_minus': '0',
#      'tp': '50',
#      'postseason': 'Did not make playoffs',
#      '156': 'https://www.eliteprospects.com/team/156/ac-zlin'},
#     '11.': {'team': 'HC Plzeň',
#      'gp': '52',
#      'w': '19',
#      't': '9',
#      'l': '24',
#      'otw': '-',
#      'otl': '-',
#      'gf': '155',
#      'ga': '172',
#      'plus_minus': '-17',
#      'tp': '47',
#      'postseason': 'Did not make playoffs',
#      '637': 'https://www.eliteprospects.com/team/637/hc-plze%C5%88'},
#     '12.': {'team': 'HC Olomouc',
#      'gp': '52',
#      'w': '16',
#      't': '11',
#      'l': '25',
#      'otw': '-',
#      'otl': '-',
#      'gf': '122',
#      'ga': '155',
#      'plus_minus': '-33',
#      'tp': '43',
#      'postseason': 'Did not make playoffs',
#      '1240': 'https://www.eliteprospects.com/team/1240/hc-olomouc'},
#     '13.': {'team': 'HC Dukla Jihlava',
#      'gp': '52',
#      'w': '13',
#      't': '10',
#      'l': '29',
#      'otw': '-',
#      'otl': '-',
#      'gf': '140',
#      'ga': '187',
#      'plus_minus': '-47',
#      'tp': '36',
#      'postseason': 'Saved in relegation',
#      '1163': 'https://www.eliteprospects.com/team/1163/hc-dukla-jihlava'},
#     '14.': {'team': 'HC Slezan Opava',
#      'gp': '52',
#      'w': '10',
#      't': '7',
#      'l': '35',
#      'otw': '-',
#      'otl': '-',
#      'gf': '125',
#      'ga': '203',
#      'plus_minus': '-78',
#      'tp': '27',
#      'postseason': 'Saved in relegation',
#      '1189': 'https://www.eliteprospects.com/team/1189/hc-slezan-opava'}}},
#   '1995-1996': {'main': {'1.': {'team': 'HC Sparta Praha',
#      'gp': '40',
#      'w': '27',
#      't': '3',
#      'l': '10',
#      'otw': '-',
#      'otl': '-',
#      'gf': '152',
#      'ga': '108',
#      'plus_minus': '44',
#      'tp': '57',
#      'postseason': 'Semifinal loss',
#      '164': 'https://www.eliteprospects.com/team/164/hc-sparta-praha'},
#     '2.': {'team': 'HC Vsetín',
#      'gp': '40',
#      'w': '24',
#      't': '7',
#      'l': '9',
#      'otw': '-',
#      'otl': '-',
#      'gf': '149',
#      'ga': '85',
#      'plus_minus': '64',
#      'tp': '55',
#      'postseason': 'Champion',
#      '5337': 'https://www.eliteprospects.com/team/5337/hc-vsetin'},
#     '3.': {'team': 'HC České Budějovice',
#      'gp': '40',
#      'w': '20',
#      't': '9',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '120',
#      'ga': '85',
#      'plus_minus': '35',
#      'tp': '49',
#      'postseason': 'Semifinal loss',
#      '154': 'https://www.eliteprospects.com/team/154/hc-%C4%8Ceske-bud%C4%9Bjovice'},
#     '4.': {'team': 'HC Litvínov',
#      'gp': '40',
#      'w': '21',
#      't': '7',
#      'l': '12',
#      'otw': '-',
#      'otl': '-',
#      'gf': '155',
#      'ga': '117',
#      'plus_minus': '38',
#      'tp': '49',
#      'postseason': 'Final loss',
#      '155': 'https://www.eliteprospects.com/team/155/hc-litvinov'},
#     '5.': {'team': 'AC Zlín',
#      'gp': '40',
#      'w': '20',
#      't': '6',
#      'l': '14',
#      'otw': '-',
#      'otl': '-',
#      'gf': '126',
#      'ga': '111',
#      'plus_minus': '15',
#      'tp': '46',
#      'postseason': 'Quarterfinal loss',
#      '156': 'https://www.eliteprospects.com/team/156/ac-zlin'},
#     '6.': {'team': 'HC Slavia Praha',
#      'gp': '40',
#      'w': '18',
#      't': '5',
#      'l': '17',
#      'otw': '-',
#      'otl': '-',
#      'gf': '148',
#      'ga': '140',
#      'plus_minus': '8',
#      'tp': '41',
#      'postseason': 'Quarterfinal loss',
#      '162': 'https://www.eliteprospects.com/team/162/hc-slavia-praha'},
#     '7.': {'team': 'HC Olomouc',
#      'gp': '40',
#      'w': '16',
#      't': '8',
#      'l': '16',
#      'otw': '-',
#      'otl': '-',
#      'gf': '112',
#      'ga': '109',
#      'plus_minus': '3',
#      'tp': '40',
#      'postseason': 'Playoffs Qualifier loss',
#      '1240': 'https://www.eliteprospects.com/team/1240/hc-olomouc'},
#     '8.': {'team': 'HC Kladno',
#      'gp': '40',
#      'w': '17',
#      't': '5',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '127',
#      'ga': '131',
#      'plus_minus': '-4',
#      'tp': '39',
#      'postseason': 'Quarterfinal loss',
#      '646': 'https://www.eliteprospects.com/team/646/hc-kladno'},
#     '9.': {'team': 'HC Vítkovice',
#      'gp': '40',
#      'w': '13',
#      't': '11',
#      'l': '16',
#      'otw': '-',
#      'otl': '-',
#      'gf': '105',
#      'ga': '121',
#      'plus_minus': '-16',
#      'tp': '37',
#      'postseason': 'Playoffs Qualifier loss',
#      '772': 'https://www.eliteprospects.com/team/772/hc-vitkovice'},
#     '10.': {'team': 'HC Dukla Jihlava',
#      'gp': '40',
#      'w': '13',
#      't': '9',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '115',
#      'ga': '142',
#      'plus_minus': '-27',
#      'tp': '35',
#      'postseason': 'Quarterfinal loss',
#      '1163': 'https://www.eliteprospects.com/team/1163/hc-dukla-jihlava'},
#     '11.': {'team': 'HC Plzeň',
#      'gp': '40',
#      'w': '12',
#      't': '7',
#      'l': '21',
#      'otw': '-',
#      'otl': '-',
#      'gf': '103',
#      'ga': '134',
#      'plus_minus': '-31',
#      'tp': '31',
#      'postseason': 'Playoffs Qualifier loss',
#      '637': 'https://www.eliteprospects.com/team/637/hc-plze%C5%88'},
#     '12.': {'team': 'HC Třinec',
#      'gp': '40',
#      'w': '12',
#      't': '6',
#      'l': '22',
#      'otw': '-',
#      'otl': '-',
#      'gf': '128',
#      'ga': '162',
#      'plus_minus': '-34',
#      'tp': '30',
#      'postseason': 'Playoffs Qualifier loss',
#      '161': 'https://www.eliteprospects.com/team/161/hc-t%C5%99inec'},
#     '13.': {'team': 'HC Pardubice',
#      'gp': '40',
#      'w': '12',
#      't': '4',
#      'l': '24',
#      'otw': '-',
#      'otl': '-',
#      'gf': '103',
#      'ga': '128',
#      'plus_minus': '-25',
#      'tp': '28',
#      'postseason': 'Saved in relegation',
#      '159': 'https://www.eliteprospects.com/team/159/hc-pardubice'},
#     '14.': {'team': 'HC Kometa Brno',
#      'gp': '40',
#      'w': '9',
#      't': '5',
#      'l': '26',
#      'otw': '-',
#      'otl': '-',
#      'gf': '95',
#      'ga': '165',
#      'plus_minus': '-70',
#      'tp': '23',
#      'postseason': 'Relegated',
#      '1190': 'https://www.eliteprospects.com/team/1190/hc-kometa-brno'}}},
#   '1994-1995': {'main': {'1.': {'team': 'HC Vsetín',
#      'gp': '44',
#      'w': '23',
#      't': '8',
#      'l': '13',
#      'otw': '-',
#      'otl': '-',
#      'gf': '141',
#      'ga': '107',
#      'plus_minus': '34',
#      'tp': '54',
#      'postseason': 'Champion',
#      '5337': 'https://www.eliteprospects.com/team/5337/hc-vsetin'},
#     '2.': {'team': 'HC Kladno',
#      'gp': '44',
#      'w': '24',
#      't': '6',
#      'l': '14',
#      'otw': '-',
#      'otl': '-',
#      'gf': '178',
#      'ga': '142',
#      'plus_minus': '36',
#      'tp': '54',
#      'postseason': 'Semifinal loss',
#      '646': 'https://www.eliteprospects.com/team/646/hc-kladno'},
#     '3.': {'team': 'HC Olomouc',
#      'gp': '44',
#      'w': '19',
#      't': '10',
#      'l': '15',
#      'otw': '-',
#      'otl': '-',
#      'gf': '130',
#      'ga': '124',
#      'plus_minus': '6',
#      'tp': '48',
#      'postseason': 'Quarterfinal loss',
#      '1240': 'https://www.eliteprospects.com/team/1240/hc-olomouc'},
#     '4.': {'team': 'AC Zlín',
#      'gp': '44',
#      'w': '20',
#      't': '8',
#      'l': '16',
#      'otw': '-',
#      'otl': '-',
#      'gf': '158',
#      'ga': '149',
#      'plus_minus': '9',
#      'tp': '48',
#      'postseason': 'Final loss',
#      '156': 'https://www.eliteprospects.com/team/156/ac-zlin'},
#     '5.': {'team': 'HC Plzeň',
#      'gp': '44',
#      'w': '16',
#      't': '14',
#      'l': '14',
#      'otw': '-',
#      'otl': '-',
#      'gf': '118',
#      'ga': '112',
#      'plus_minus': '6',
#      'tp': '46',
#      'postseason': 'Quarterfinal loss',
#      '637': 'https://www.eliteprospects.com/team/637/hc-plze%C5%88'},
#     '6.': {'team': 'HC České Budějovice',
#      'gp': '44',
#      'w': '20',
#      't': '6',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '142',
#      'ga': '124',
#      'plus_minus': '18',
#      'tp': '46',
#      'postseason': 'Semifinal loss',
#      '154': 'https://www.eliteprospects.com/team/154/hc-%C4%8Ceske-bud%C4%9Bjovice'},
#     '7.': {'team': 'HC Slavia Praha',
#      'gp': '44',
#      'w': '18',
#      't': '7',
#      'l': '19',
#      'otw': '-',
#      'otl': '-',
#      'gf': '133',
#      'ga': '164',
#      'plus_minus': '-31',
#      'tp': '43',
#      'postseason': 'Quarterfinal loss',
#      '162': 'https://www.eliteprospects.com/team/162/hc-slavia-praha'},
#     '8.': {'team': 'HC Litvínov',
#      'gp': '44',
#      'w': '18',
#      't': '6',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '149',
#      'ga': '143',
#      'plus_minus': '6',
#      'tp': '42',
#      'postseason': 'Quarterfinal loss',
#      '155': 'https://www.eliteprospects.com/team/155/hc-litvinov'},
#     '9.': {'team': 'HC Sparta Praha',
#      'gp': '44',
#      'w': '16',
#      't': '9',
#      'l': '19',
#      'otw': '-',
#      'otl': '-',
#      'gf': '123',
#      'ga': '129',
#      'plus_minus': '-6',
#      'tp': '41',
#      'postseason': 'Saved in play-out',
#      '164': 'https://www.eliteprospects.com/team/164/hc-sparta-praha'},
#     '10.': {'team': 'HC Vítkovice',
#      'gp': '44',
#      'w': '18',
#      't': '5',
#      'l': '21',
#      'otw': '-',
#      'otl': '-',
#      'gf': '144',
#      'ga': '156',
#      'plus_minus': '-12',
#      'tp': '41',
#      'postseason': 'Saved in play-out',
#      '772': 'https://www.eliteprospects.com/team/772/hc-vitkovice'},
#     '11.': {'team': 'HC Pardubice',
#      'gp': '44',
#      'w': '13',
#      't': '11',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '134',
#      'ga': '151',
#      'plus_minus': '-17',
#      'tp': '37',
#      'postseason': 'Saved in play-out',
#      '159': 'https://www.eliteprospects.com/team/159/hc-pardubice'},
#     '12.': {'team': 'HC Dukla Jihlava',
#      'gp': '44',
#      'w': '12',
#      't': '4',
#      'l': '28',
#      'otw': '-',
#      'otl': '-',
#      'gf': '117',
#      'ga': '166',
#      'plus_minus': '-49',
#      'tp': '28',
#      'postseason': 'Saved in play-out',
#      '1163': 'https://www.eliteprospects.com/team/1163/hc-dukla-jihlava'}}},
#   '1993-1994': {'main': {'1.': {'team': 'HC Kladno',
#      'gp': '44',
#      'w': '24',
#      't': '8',
#      'l': '12',
#      'otw': '-',
#      'otl': '-',
#      'gf': '182',
#      'ga': '151',
#      'plus_minus': '31',
#      'tp': '56',
#      'postseason': 'Semifinal loss',
#      '646': 'https://www.eliteprospects.com/team/646/hc-kladno'},
#     '2.': {'team': 'HC České Budějovice',
#      'gp': '44',
#      'w': '23',
#      't': '6',
#      'l': '15',
#      'otw': '-',
#      'otl': '-',
#      'gf': '163',
#      'ga': '120',
#      'plus_minus': '43',
#      'tp': '52',
#      'postseason': 'Quarterfinal loss',
#      '154': 'https://www.eliteprospects.com/team/154/hc-%C4%8Ceske-bud%C4%9Bjovice'},
#     '3.': {'team': 'HC Vítkovice',
#      'gp': '44',
#      'w': '19',
#      't': '11',
#      'l': '14',
#      'otw': '-',
#      'otl': '-',
#      'gf': '162',
#      'ga': '138',
#      'plus_minus': '24',
#      'tp': '49',
#      'postseason': 'Quarterfinal loss',
#      '772': 'https://www.eliteprospects.com/team/772/hc-vitkovice'},
#     '4.': {'team': 'AC Zlín',
#      'gp': '44',
#      'w': '21',
#      't': '7',
#      'l': '16',
#      'otw': '-',
#      'otl': '-',
#      'gf': '154',
#      'ga': '163',
#      'plus_minus': '-9',
#      'tp': '49',
#      'postseason': 'Quarterfinal loss',
#      '156': 'https://www.eliteprospects.com/team/156/ac-zlin'},
#     '5.': {'team': 'HC Sparta Praha',
#      'gp': '44',
#      'w': '21',
#      't': '6',
#      'l': '17',
#      'otw': '-',
#      'otl': '-',
#      'gf': '162',
#      'ga': '129',
#      'plus_minus': '33',
#      'tp': '48',
#      'postseason': 'Semifinal loss',
#      '164': 'https://www.eliteprospects.com/team/164/hc-sparta-praha'},
#     '6.': {'team': 'HC Pardubice',
#      'gp': '44',
#      'w': '22',
#      't': '4',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '142',
#      'ga': '128',
#      'plus_minus': '14',
#      'tp': '48',
#      'postseason': 'Final loss',
#      '159': 'https://www.eliteprospects.com/team/159/hc-pardubice'},
#     '7.': {'team': 'HC Olomouc',
#      'gp': '44',
#      'w': '19',
#      't': '7',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '116',
#      'ga': '123',
#      'plus_minus': '-7',
#      'tp': '45',
#      'postseason': 'Champion',
#      '1240': 'https://www.eliteprospects.com/team/1240/hc-olomouc'},
#     '8.': {'team': 'HC Litvínov',
#      'gp': '44',
#      'w': '18',
#      't': '8',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '161',
#      'ga': '154',
#      'plus_minus': '7',
#      'tp': '44',
#      'postseason': 'Quarterfinal loss',
#      '155': 'https://www.eliteprospects.com/team/155/hc-litvinov'},
#     '9.': {'team': 'HC Plzeň',
#      'gp': '44',
#      'w': '15',
#      't': '8',
#      'l': '21',
#      'otw': '-',
#      'otl': '-',
#      'gf': '132',
#      'ga': '140',
#      'plus_minus': '-8',
#      'tp': '38',
#      'postseason': 'Saved in play-out',
#      '637': 'https://www.eliteprospects.com/team/637/hc-plze%C5%88'},
#     '10.': {'team': 'ASD Dukla Jihlava',
#      'gp': '44',
#      'w': '16',
#      't': '6',
#      'l': '22',
#      'otw': '-',
#      'otl': '-',
#      'gf': '131',
#      'ga': '143',
#      'plus_minus': '-12',
#      'tp': '38',
#      'postseason': 'Saved in play-out',
#      '1163': 'https://www.eliteprospects.com/team/1163/asd-dukla-jihlava'},
#     '11.': {'team': 'HC Stadion Hradec Králové',
#      'gp': '44',
#      'w': '12',
#      't': '11',
#      'l': '21',
#      'otw': '-',
#      'otl': '-',
#      'gf': '133',
#      'ga': '163',
#      'plus_minus': '-30',
#      'tp': '35',
#      'postseason': 'Relegated',
#      '15659': 'https://www.eliteprospects.com/team/15659/hc-stadion-hradec-kralove'},
#     '12.': {'team': 'KLH Jindrichuv Hradec',
#      'gp': '44',
#      'w': '10',
#      't': '6',
#      'l': '28',
#      'otw': '-',
#      'otl': '-',
#      'gf': '107',
#      'ga': '193',
#      'plus_minus': '-86',
#      'tp': '26',
#      'postseason': 'Relegated',
#      '3109': 'https://www.eliteprospects.com/team/3109/klh-jindrichuv-hradec'}}}}}

# %%
file_name = "league_dict.json"
ld_path = test_path + file_name
with open(ld_path, "w") as ld:
    json.dump(league_data, ld)

# %%
file_name = "league_dict.json"
ld_path = test_path + file_name
f = open(ld_path)
league_data = json.load(f)

# %%
league_data
# Out:
# {'long_name': 'National Hockey League',
#  'achievements_names': ['NHA Stanley Cup Champion',
#   'NHL All-Rookie Team',
#   'NHL All-Star Game',
#   'NHL Best Defenseman (Norris Trophy)',
#   'NHL Best Defenseman (Norris Trophy) Finalist',
#   'NHL Best GAA',
#   'NHL Best Goalie (Vezina Trophy)',
#   'NHL Best Goalie (Vezina Trophy) Finalist',
#   'NHL Best Plus/Minus',
#   'NHL Best SVS%',
#   'NHL Coach of the Year (Jack Adams Award)',
#   'NHL Contribution to U.S. Hockey (Lester Patrick Trophy)',
#   'NHL First All-Star Team',
#   'NHL Foundation Player Award',
#   'NHL General Manager of the Year',
#   'NHL Gentleman Conduct (Lady Byng Trophy)',
#   'NHL Gentleman Conduct (Lady Byng Trophy) Finalist',
#   'NHL Leadership-Humanitarian Award (King Clancy Trophy)',
#   'NHL Lowest GA (Jennings Trophy)',
#   'NHL Mark Messier Leadership Award',
#   'NHL Most Assists',
#   'NHL Most Assists by Defenseman',
#   'NHL Most Assists by Rookie',
#   'NHL Most Goals (Maurice Richard Trophy)',
#   'NHL Most Goals by Defenseman',
#   'NHL Most Goals by Rookie',
#   'NHL Most Penalized Player',
#   'NHL Most Points (Art Ross Trophy)',
#   'NHL Most Points by Defenseman',
#   'NHL Most Points by Rookie',
#   'NHL Most Valuable Player (Hart Trophy)',
#   'NHL Most Valuable Player (Hart Trophy) Finalist',
#   'NHL MVP Selected by NHLPA (Ted Lindsay Award)',
#   'NHL Playoffs Most Assists',
#   'NHL Playoffs Most Goals',
#   'NHL Playoffs Most Points',
#   'NHL Playoffs Most Points by Defenseman',
#   'NHL Rookie of the Year (Calder Trophy)',
#   'NHL Rookie of the Year (Calder Trophy) Finalist',
#   'NHL Second All-Star Team',
#   'NHL Sportsmanship Award (Bill Masterton Trophy)',
#   'NHL Sportsmanship Award (Bill Masterton Trophy) Finalist',
#   'NHL Stanley Cup Champion',
#   'NHL Stanley Cup Clinching Goal',
#   'NHL Stanley Cup MVP (Conn Smythe Trophy)',
#   'NHL Top Defensive Forward (Frank J. Selke Trophy)',
#   'NHL Top Defensive Forward (Selke Trophy) Finalist',
#   'NHL YoungStars Roster'],
#  'season_tables': {'2022-2023': {'Eastern/Atlantic Division': {'1.': {'team': 'Boston Bruins',
#      'gp': '82',
#      'w': '54',
#      't': '-',
#      'l': '12',
#      'otw': '11',
#      'otl': '5',
#      'gf': '305',
#      'ga': '177',
#      'plus_minus': '128',
#      'tp': '135',
#      'postseason': 'Conference QF loss'},
#     '2.': {'team': 'Toronto Maple Leafs',
#      'gp': '82',
#      'w': '42',
#      't': '-',
#      'l': '21',
#      'otw': '8',
#      'otl': '11',
#      'gf': '279',
#      'ga': '222',
#      'plus_minus': '57',
#      'tp': '111',
#      'postseason': 'Conference SF loss'},
#     '3.': {'team': 'Tampa Bay Lightning',
#      'gp': '82',
#      'w': '38',
#      't': '-',
#      'l': '30',
#      'otw': '8',
#      'otl': '6',
#      'gf': '283',
#      'ga': '254',
#      'plus_minus': '29',
#      'tp': '98',
#      'postseason': 'Conference QF loss'},
#     '4.': {'team': 'Florida Panthers',
#      'gp': '82',
#      'w': '36',
#      't': '-',
#      'l': '32',
#      'otw': '6',
#      'otl': '8',
#      'gf': '290',
#      'ga': '273',
#      'plus_minus': '17',
#      'tp': '92',
#      'postseason': 'Final loss'},
#     '5.': {'team': 'Buffalo Sabres',
#      'gp': '82',
#      'w': '30',
#      't': '-',
#      'l': '33',
#      'otw': '12',
#      'otl': '7',
#      'gf': '296',
#      'ga': '300',
#      'plus_minus': '-4',
#      'tp': '91',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'Ottawa Senators',
#      'gp': '82',
#      'w': '31',
#      't': '-',
#      'l': '35',
#      'otw': '8',
#      'otl': '8',
#      'gf': '261',
#      'ga': '271',
#      'plus_minus': '-10',
#      'tp': '86',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'Detroit Red Wings',
#      'gp': '82',
#      'w': '28',
#      't': '-',
#      'l': '37',
#      'otw': '7',
#      'otl': '10',
#      'gf': '240',
#      'ga': '279',
#      'plus_minus': '-39',
#      'tp': '80',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Montréal Canadiens',
#      'gp': '82',
#      'w': '21',
#      't': '-',
#      'l': '45',
#      'otw': '10',
#      'otl': '6',
#      'gf': '232',
#      'ga': '307',
#      'plus_minus': '-75',
#      'tp': '68',
#      'postseason': 'Did not make playoffs'}},
#    'Eastern/Metropolitan Division': {'1.': {'team': 'Carolina Hurricanes',
#      'gp': '82',
#      'w': '39',
#      't': '-',
#      'l': '21',
#      'otw': '13',
#      'otl': '9',
#      'gf': '266',
#      'ga': '213',
#      'plus_minus': '53',
#      'tp': '113',
#      'postseason': 'Conference Final loss'},
#     '2.': {'team': 'New Jersey Devils',
#      'gp': '82',
#      'w': '39',
#      't': '-',
#      'l': '22',
#      'otw': '13',
#      'otl': '8',
#      'gf': '291',
#      'ga': '226',
#      'plus_minus': '65',
#      'tp': '112',
#      'postseason': 'Conference SF loss'},
#     '3.': {'team': 'New York Rangers',
#      'gp': '82',
#      'w': '37',
#      't': '-',
#      'l': '22',
#      'otw': '10',
#      'otl': '13',
#      'gf': '277',
#      'ga': '219',
#      'plus_minus': '58',
#      'tp': '107',
#      'postseason': 'Conference QF loss'},
#     '4.': {'team': 'New York Islanders',
#      'gp': '82',
#      'w': '36',
#      't': '-',
#      'l': '31',
#      'otw': '6',
#      'otl': '9',
#      'gf': '243',
#      'ga': '222',
#      'plus_minus': '21',
#      'tp': '93',
#      'postseason': 'Conference QF loss'},
#     '5.': {'team': 'Pittsburgh Penguins',
#      'gp': '82',
#      'w': '31',
#      't': '-',
#      'l': '31',
#      'otw': '9',
#      'otl': '11',
#      'gf': '262',
#      'ga': '264',
#      'plus_minus': '-2',
#      'tp': '91',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'Washington Capitals',
#      'gp': '82',
#      'w': '27',
#      't': '-',
#      'l': '37',
#      'otw': '8',
#      'otl': '10',
#      'gf': '255',
#      'ga': '265',
#      'plus_minus': '-10',
#      'tp': '80',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'Philadelphia Flyers',
#      'gp': '82',
#      'w': '26',
#      't': '-',
#      'l': '38',
#      'otw': '5',
#      'otl': '13',
#      'gf': '222',
#      'ga': '277',
#      'plus_minus': '-55',
#      'tp': '75',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Columbus Blue Jackets',
#      'gp': '82',
#      'w': '15',
#      't': '-',
#      'l': '48',
#      'otw': '10',
#      'otl': '9',
#      'gf': '214',
#      'ga': '330',
#      'plus_minus': '-116',
#      'tp': '59',
#      'postseason': 'Did not make playoffs'}},
#    'Western/Central Division': {'1.': {'team': 'Colorado Avalanche',
#      'gp': '82',
#      'w': '36',
#      't': '-',
#      'l': '24',
#      'otw': '15',
#      'otl': '7',
#      'gf': '280',
#      'ga': '226',
#      'plus_minus': '54',
#      'tp': '109',
#      'postseason': 'Conference QF loss'},
#     '2.': {'team': 'Dallas Stars',
#      'gp': '82',
#      'w': '39',
#      't': '-',
#      'l': '21',
#      'otw': '8',
#      'otl': '14',
#      'gf': '285',
#      'ga': '218',
#      'plus_minus': '67',
#      'tp': '108',
#      'postseason': 'Conference Final loss'},
#     '3.': {'team': 'Minnesota Wild',
#      'gp': '82',
#      'w': '34',
#      't': '-',
#      'l': '25',
#      'otw': '12',
#      'otl': '11',
#      'gf': '246',
#      'ga': '225',
#      'plus_minus': '21',
#      'tp': '103',
#      'postseason': 'Conference QF loss'},
#     '4.': {'team': 'Winnipeg Jets',
#      'gp': '82',
#      'w': '36',
#      't': '-',
#      'l': '33',
#      'otw': '10',
#      'otl': '3',
#      'gf': '247',
#      'ga': '225',
#      'plus_minus': '22',
#      'tp': '95',
#      'postseason': 'Conference QF loss'},
#     '5.': {'team': 'Nashville Predators',
#      'gp': '82',
#      'w': '29',
#      't': '-',
#      'l': '32',
#      'otw': '13',
#      'otl': '8',
#      'gf': '229',
#      'ga': '238',
#      'plus_minus': '-9',
#      'tp': '92',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'St. Louis Blues',
#      'gp': '82',
#      'w': '27',
#      't': '-',
#      'l': '38',
#      'otw': '10',
#      'otl': '7',
#      'gf': '263',
#      'ga': '301',
#      'plus_minus': '-38',
#      'tp': '81',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'Arizona Coyotes',
#      'gp': '82',
#      'w': '20',
#      't': '-',
#      'l': '40',
#      'otw': '8',
#      'otl': '14',
#      'gf': '228',
#      'ga': '299',
#      'plus_minus': '-71',
#      'tp': '70',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Chicago Blackhawks',
#      'gp': '82',
#      'w': '18',
#      't': '-',
#      'l': '49',
#      'otw': '8',
#      'otl': '7',
#      'gf': '204',
#      'ga': '301',
#      'plus_minus': '-97',
#      'tp': '59',
#      'postseason': 'Did not make playoffs'}},
#    'Western/Pacific Division': {'1.': {'team': 'Vegas Golden Knights',
#      'gp': '82',
#      'w': '38',
#      't': '-',
#      'l': '22',
#      'otw': '13',
#      'otl': '9',
#      'gf': '272',
#      'ga': '229',
#      'plus_minus': '43',
#      'tp': '111',
#      'postseason': 'Champion'},
#     '2.': {'team': 'Edmonton Oilers',
#      'gp': '82',
#      'w': '45',
#      't': '-',
#      'l': '23',
#      'otw': '5',
#      'otl': '9',
#      'gf': '325',
#      'ga': '260',
#      'plus_minus': '65',
#      'tp': '109',
#      'postseason': 'Conference SF loss'},
#     '3.': {'team': 'Los Angeles Kings',
#      'gp': '82',
#      'w': '37',
#      't': '-',
#      'l': '25',
#      'otw': '10',
#      'otl': '10',
#      'gf': '280',
#      'ga': '257',
#      'plus_minus': '23',
#      'tp': '104',
#      'postseason': 'Conference QF loss'},
#     '4.': {'team': 'Seattle Kraken',
#      'gp': '82',
#      'w': '37',
#      't': '-',
#      'l': '28',
#      'otw': '9',
#      'otl': '8',
#      'gf': '289',
#      'ga': '256',
#      'plus_minus': '33',
#      'tp': '100',
#      'postseason': 'Conference SF loss'},
#     '5.': {'team': 'Calgary Flames',
#      'gp': '82',
#      'w': '31',
#      't': '-',
#      'l': '27',
#      'otw': '7',
#      'otl': '17',
#      'gf': '260',
#      'ga': '252',
#      'plus_minus': '8',
#      'tp': '93',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'Vancouver Canucks',
#      'gp': '82',
#      'w': '24',
#      't': '-',
#      'l': '37',
#      'otw': '14',
#      'otl': '7',
#      'gf': '276',
#      'ga': '298',
#      'plus_minus': '-22',
#      'tp': '83',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'San Jose Sharks',
#      'gp': '82',
#      'w': '16',
#      't': '-',
#      'l': '44',
#      'otw': '6',
#      'otl': '16',
#      'gf': '234',
#      'ga': '321',
#      'plus_minus': '-87',
#      'tp': '60',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Anaheim Ducks',
#      'gp': '82',
#      'w': '13',
#      't': '-',
#      'l': '47',
#      'otw': '10',
#      'otl': '12',
#      'gf': '209',
#      'ga': '338',
#      'plus_minus': '-129',
#      'tp': '58',
#      'postseason': 'Did not make playoffs'}}},
#   '2021-2022': {'Atlantic Division': {'1.': {'team': 'Florida Panthers',
#      'gp': '82',
#      'w': '42',
#      't': '-',
#      'l': '18',
#      'otw': '16',
#      'otl': '6',
#      'gf': '340',
#      'ga': '246',
#      'plus_minus': '94',
#      'tp': '122',
#      'postseason': 'Conference SF loss'},
#     '2.': {'team': 'Toronto Maple Leafs',
#      'gp': '82',
#      'w': '45',
#      't': '-',
#      'l': '21',
#      'otw': '9',
#      'otl': '7',
#      'gf': '315',
#      'ga': '253',
#      'plus_minus': '62',
#      'tp': '115',
#      'postseason': 'Conference QF loss'},
#     '3.': {'team': 'Tampa Bay Lightning',
#      'gp': '82',
#      'w': '39',
#      't': '-',
#      'l': '23',
#      'otw': '12',
#      'otl': '8',
#      'gf': '287',
#      'ga': '233',
#      'plus_minus': '54',
#      'tp': '110',
#      'postseason': 'Final loss'},
#     '4.': {'team': 'Boston Bruins',
#      'gp': '82',
#      'w': '40',
#      't': '-',
#      'l': '26',
#      'otw': '11',
#      'otl': '5',
#      'gf': '255',
#      'ga': '220',
#      'plus_minus': '35',
#      'tp': '107',
#      'postseason': 'Conference QF loss'},
#     '5.': {'team': 'Buffalo Sabres',
#      'gp': '82',
#      'w': '25',
#      't': '-',
#      'l': '39',
#      'otw': '7',
#      'otl': '11',
#      'gf': '232',
#      'ga': '290',
#      'plus_minus': '-58',
#      'tp': '75',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'Detroit Red Wings',
#      'gp': '82',
#      'w': '21',
#      't': '-',
#      'l': '40',
#      'otw': '11',
#      'otl': '10',
#      'gf': '230',
#      'ga': '312',
#      'plus_minus': '-82',
#      'tp': '74',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'Ottawa Senators',
#      'gp': '82',
#      'w': '26',
#      't': '-',
#      'l': '42',
#      'otw': '7',
#      'otl': '7',
#      'gf': '227',
#      'ga': '266',
#      'plus_minus': '-39',
#      'tp': '73',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Montréal Canadiens',
#      'gp': '82',
#      'w': '16',
#      't': '-',
#      'l': '49',
#      'otw': '6',
#      'otl': '11',
#      'gf': '221',
#      'ga': '319',
#      'plus_minus': '-98',
#      'tp': '55',
#      'postseason': 'Did not make playoffs'}},
#    'Central Division': {'1.': {'team': 'Colorado Avalanche',
#      'gp': '82',
#      'w': '46',
#      't': '-',
#      'l': '19',
#      'otw': '10',
#      'otl': '7',
#      'gf': '312',
#      'ga': '234',
#      'plus_minus': '78',
#      'tp': '119',
#      'postseason': 'Champion'},
#     '2.': {'team': 'Minnesota Wild',
#      'gp': '82',
#      'w': '37',
#      't': '-',
#      'l': '22',
#      'otw': '16',
#      'otl': '7',
#      'gf': '310',
#      'ga': '253',
#      'plus_minus': '57',
#      'tp': '113',
#      'postseason': 'Conference QF loss'},
#     '3.': {'team': 'St. Louis Blues',
#      'gp': '82',
#      'w': '43',
#      't': '-',
#      'l': '22',
#      'otw': '6',
#      'otl': '11',
#      'gf': '311',
#      'ga': '242',
#      'plus_minus': '69',
#      'tp': '109',
#      'postseason': 'Conference SF loss'},
#     '4.': {'team': 'Dallas Stars',
#      'gp': '82',
#      'w': '31',
#      't': '-',
#      'l': '30',
#      'otw': '15',
#      'otl': '6',
#      'gf': '238',
#      'ga': '246',
#      'plus_minus': '-8',
#      'tp': '98',
#      'postseason': 'Conference QF loss'},
#     '5.': {'team': 'Nashville Predators',
#      'gp': '82',
#      'w': '35',
#      't': '-',
#      'l': '30',
#      'otw': '10',
#      'otl': '7',
#      'gf': '266',
#      'ga': '252',
#      'plus_minus': '14',
#      'tp': '97',
#      'postseason': 'Conference QF loss'},
#     '6.': {'team': 'Winnipeg Jets',
#      'gp': '82',
#      'w': '32',
#      't': '-',
#      'l': '32',
#      'otw': '7',
#      'otl': '11',
#      'gf': '252',
#      'ga': '257',
#      'plus_minus': '-5',
#      'tp': '89',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'Chicago Blackhawks',
#      'gp': '82',
#      'w': '16',
#      't': '-',
#      'l': '42',
#      'otw': '12',
#      'otl': '12',
#      'gf': '219',
#      'ga': '291',
#      'plus_minus': '-72',
#      'tp': '68',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Arizona Coyotes',
#      'gp': '82',
#      'w': '18',
#      't': '-',
#      'l': '50',
#      'otw': '7',
#      'otl': '7',
#      'gf': '207',
#      'ga': '313',
#      'plus_minus': '-106',
#      'tp': '57',
#      'postseason': 'Did not make playoffs'}},
#    'Metropolitan Division': {'1.': {'team': 'Carolina Hurricanes',
#      'gp': '82',
#      'w': '47',
#      't': '-',
#      'l': '20',
#      'otw': '7',
#      'otl': '8',
#      'gf': '278',
#      'ga': '202',
#      'plus_minus': '76',
#      'tp': '116',
#      'postseason': 'Conference SF loss'},
#     '2.': {'team': 'New York Rangers',
#      'gp': '82',
#      'w': '44',
#      't': '-',
#      'l': '24',
#      'otw': '8',
#      'otl': '6',
#      'gf': '254',
#      'ga': '207',
#      'plus_minus': '47',
#      'tp': '110',
#      'postseason': 'Conference Final loss'},
#     '3.': {'team': 'Pittsburgh Penguins',
#      'gp': '82',
#      'w': '37',
#      't': '-',
#      'l': '25',
#      'otw': '9',
#      'otl': '11',
#      'gf': '272',
#      'ga': '229',
#      'plus_minus': '43',
#      'tp': '103',
#      'postseason': 'Conference QF loss'},
#     '4.': {'team': 'Washington Capitals',
#      'gp': '82',
#      'w': '35',
#      't': '-',
#      'l': '26',
#      'otw': '9',
#      'otl': '12',
#      'gf': '275',
#      'ga': '245',
#      'plus_minus': '30',
#      'tp': '100',
#      'postseason': 'Conference QF loss'},
#     '5.': {'team': 'New York Islanders',
#      'gp': '82',
#      'w': '34',
#      't': '-',
#      'l': '35',
#      'otw': '3',
#      'otl': '10',
#      'gf': '231',
#      'ga': '237',
#      'plus_minus': '-6',
#      'tp': '84',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'Columbus Blue Jackets',
#      'gp': '82',
#      'w': '26',
#      't': '-',
#      'l': '38',
#      'otw': '11',
#      'otl': '7',
#      'gf': '262',
#      'ga': '300',
#      'plus_minus': '-38',
#      'tp': '81',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'New Jersey Devils',
#      'gp': '82',
#      'w': '19',
#      't': '-',
#      'l': '46',
#      'otw': '8',
#      'otl': '9',
#      'gf': '248',
#      'ga': '307',
#      'plus_minus': '-59',
#      'tp': '63',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Philadelphia Flyers',
#      'gp': '82',
#      'w': '20',
#      't': '-',
#      'l': '46',
#      'otw': '5',
#      'otl': '11',
#      'gf': '211',
#      'ga': '298',
#      'plus_minus': '-87',
#      'tp': '61',
#      'postseason': 'Did not make playoffs'}},
#    'Pacific Division': {'1.': {'team': 'Calgary Flames',
#      'gp': '82',
#      'w': '44',
#      't': '-',
#      'l': '21',
#      'otw': '6',
#      'otl': '11',
#      'gf': '293',
#      'ga': '208',
#      'plus_minus': '85',
#      'tp': '111',
#      'postseason': 'Conference SF loss'},
#     '2.': {'team': 'Edmonton Oilers',
#      'gp': '82',
#      'w': '38',
#      't': '-',
#      'l': '27',
#      'otw': '11',
#      'otl': '6',
#      'gf': '290',
#      'ga': '252',
#      'plus_minus': '38',
#      'tp': '104',
#      'postseason': 'Conference Final loss'},
#     '3.': {'team': 'Los Angeles Kings',
#      'gp': '82',
#      'w': '35',
#      't': '-',
#      'l': '27',
#      'otw': '9',
#      'otl': '11',
#      'gf': '239',
#      'ga': '236',
#      'plus_minus': '3',
#      'tp': '99',
#      'postseason': 'Conference QF loss'},
#     '4.': {'team': 'Vegas Golden Knights',
#      'gp': '82',
#      'w': '34',
#      't': '-',
#      'l': '31',
#      'otw': '9',
#      'otl': '8',
#      'gf': '266',
#      'ga': '248',
#      'plus_minus': '18',
#      'tp': '94',
#      'postseason': 'Did not make playoffs'},
#     '5.': {'team': 'Vancouver Canucks',
#      'gp': '82',
#      'w': '32',
#      't': '-',
#      'l': '30',
#      'otw': '8',
#      'otl': '12',
#      'gf': '249',
#      'ga': '236',
#      'plus_minus': '13',
#      'tp': '92',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'San Jose Sharks',
#      'gp': '82',
#      'w': '22',
#      't': '-',
#      'l': '37',
#      'otw': '10',
#      'otl': '13',
#      'gf': '214',
#      'ga': '264',
#      'plus_minus': '-50',
#      'tp': '77',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'Anaheim Ducks',
#      'gp': '82',
#      'w': '22',
#      't': '-',
#      'l': '37',
#      'otw': '9',
#      'otl': '14',
#      'gf': '232',
#      'ga': '271',
#      'plus_minus': '-39',
#      'tp': '76',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Seattle Kraken',
#      'gp': '82',
#      'w': '23',
#      't': '-',
#      'l': '49',
#      'otw': '4',
#      'otl': '6',
#      'gf': '216',
#      'ga': '285',
#      'plus_minus': '-69',
#      'tp': '60',
#      'postseason': 'Did not make playoffs'}}},
#   '2020-2021': {'main': {'1.': {'team': 'Colorado Avalanche',
#      'gp': '56',
#      'w': '39',
#      't': '-',
#      'l': '13',
#      'otw': '-',
#      'otl': '4',
#      'gf': '197',
#      'ga': '133',
#      'plus_minus': '64',
#      'tp': '82',
#      'postseason': 'Conference SF loss'},
#     '2.': {'team': 'Vegas Golden Knights',
#      'gp': '56',
#      'w': '40',
#      't': '-',
#      'l': '14',
#      'otw': '-',
#      'otl': '2',
#      'gf': '191',
#      'ga': '124',
#      'plus_minus': '67',
#      'tp': '82',
#      'postseason': 'Conference Final loss'},
#     '3.': {'team': 'Carolina Hurricanes',
#      'gp': '56',
#      'w': '36',
#      't': '-',
#      'l': '12',
#      'otw': '-',
#      'otl': '8',
#      'gf': '179',
#      'ga': '136',
#      'plus_minus': '43',
#      'tp': '80',
#      'postseason': 'Conference SF loss'},
#     '4.': {'team': 'Florida Panthers',
#      'gp': '56',
#      'w': '37',
#      't': '-',
#      'l': '14',
#      'otw': '-',
#      'otl': '5',
#      'gf': '189',
#      'ga': '153',
#      'plus_minus': '36',
#      'tp': '79',
#      'postseason': 'Conference QF loss'},
#     '5.': {'team': 'Pittsburgh Penguins',
#      'gp': '56',
#      'w': '37',
#      't': '-',
#      'l': '16',
#      'otw': '-',
#      'otl': '3',
#      'gf': '196',
#      'ga': '156',
#      'plus_minus': '40',
#      'tp': '77',
#      'postseason': 'Conference QF loss'},
#     '6.': {'team': 'Toronto Maple Leafs',
#      'gp': '56',
#      'w': '35',
#      't': '-',
#      'l': '14',
#      'otw': '-',
#      'otl': '7',
#      'gf': '187',
#      'ga': '148',
#      'plus_minus': '39',
#      'tp': '77',
#      'postseason': 'Conference QF loss'},
#     '7.': {'team': 'Washington Capitals',
#      'gp': '56',
#      'w': '36',
#      't': '-',
#      'l': '15',
#      'otw': '-',
#      'otl': '5',
#      'gf': '191',
#      'ga': '163',
#      'plus_minus': '28',
#      'tp': '77',
#      'postseason': 'Conference QF loss'},
#     '8.': {'team': 'Tampa Bay Lightning',
#      'gp': '56',
#      'w': '36',
#      't': '-',
#      'l': '17',
#      'otw': '-',
#      'otl': '3',
#      'gf': '181',
#      'ga': '147',
#      'plus_minus': '34',
#      'tp': '75',
#      'postseason': 'Champion'},
#     '9.': {'team': 'Minnesota Wild',
#      'gp': '56',
#      'w': '35',
#      't': '-',
#      'l': '16',
#      'otw': '-',
#      'otl': '5',
#      'gf': '181',
#      'ga': '160',
#      'plus_minus': '21',
#      'tp': '75',
#      'postseason': 'Conference QF loss'},
#     '10.': {'team': 'Boston Bruins',
#      'gp': '56',
#      'w': '33',
#      't': '-',
#      'l': '16',
#      'otw': '-',
#      'otl': '7',
#      'gf': '168',
#      'ga': '136',
#      'plus_minus': '32',
#      'tp': '73',
#      'postseason': 'Conference SF loss'},
#     '11.': {'team': 'Edmonton Oilers',
#      'gp': '56',
#      'w': '35',
#      't': '-',
#      'l': '19',
#      'otw': '-',
#      'otl': '2',
#      'gf': '183',
#      'ga': '154',
#      'plus_minus': '29',
#      'tp': '72',
#      'postseason': 'Conference QF loss'},
#     '12.': {'team': 'New York Islanders',
#      'gp': '56',
#      'w': '32',
#      't': '-',
#      'l': '17',
#      'otw': '-',
#      'otl': '7',
#      'gf': '156',
#      'ga': '128',
#      'plus_minus': '28',
#      'tp': '71',
#      'postseason': 'Conference Final loss'},
#     '13.': {'team': 'Nashville Predators',
#      'gp': '56',
#      'w': '31',
#      't': '-',
#      'l': '23',
#      'otw': '-',
#      'otl': '2',
#      'gf': '156',
#      'ga': '154',
#      'plus_minus': '2',
#      'tp': '64',
#      'postseason': 'Conference QF loss'},
#     '14.': {'team': 'Winnipeg Jets',
#      'gp': '56',
#      'w': '30',
#      't': '-',
#      'l': '23',
#      'otw': '-',
#      'otl': '3',
#      'gf': '170',
#      'ga': '154',
#      'plus_minus': '16',
#      'tp': '63',
#      'postseason': 'Conference SF loss'},
#     '15.': {'team': 'St. Louis Blues',
#      'gp': '56',
#      'w': '27',
#      't': '-',
#      'l': '20',
#      'otw': '-',
#      'otl': '9',
#      'gf': '169',
#      'ga': '170',
#      'plus_minus': '-1',
#      'tp': '63',
#      'postseason': 'Conference QF loss'},
#     '16.': {'team': 'New York Rangers',
#      'gp': '56',
#      'w': '27',
#      't': '-',
#      'l': '23',
#      'otw': '-',
#      'otl': '6',
#      'gf': '177',
#      'ga': '157',
#      'plus_minus': '20',
#      'tp': '60',
#      'postseason': 'Did not make playoffs'},
#     '17.': {'team': 'Dallas Stars',
#      'gp': '56',
#      'w': '23',
#      't': '-',
#      'l': '19',
#      'otw': '-',
#      'otl': '14',
#      'gf': '158',
#      'ga': '154',
#      'plus_minus': '4',
#      'tp': '60',
#      'postseason': 'Did not make playoffs'},
#     '18.': {'team': 'Montréal Canadiens',
#      'gp': '56',
#      'w': '24',
#      't': '-',
#      'l': '21',
#      'otw': '-',
#      'otl': '11',
#      'gf': '159',
#      'ga': '168',
#      'plus_minus': '-9',
#      'tp': '59',
#      'postseason': 'Final loss'},
#     '19.': {'team': 'Philadelphia Flyers',
#      'gp': '56',
#      'w': '25',
#      't': '-',
#      'l': '23',
#      'otw': '-',
#      'otl': '8',
#      'gf': '163',
#      'ga': '201',
#      'plus_minus': '-38',
#      'tp': '58',
#      'postseason': 'Did not make playoffs'},
#     '20.': {'team': 'Calgary Flames',
#      'gp': '55',
#      'w': '25',
#      't': '-',
#      'l': '27',
#      'otw': '-',
#      'otl': '3',
#      'gf': '150',
#      'ga': '159',
#      'plus_minus': '-9',
#      'tp': '53',
#      'postseason': 'Did not make playoffs'},
#     '21.': {'team': 'Chicago Blackhawks',
#      'gp': '56',
#      'w': '24',
#      't': '-',
#      'l': '25',
#      'otw': '-',
#      'otl': '7',
#      'gf': '161',
#      'ga': '186',
#      'plus_minus': '-25',
#      'tp': '55',
#      'postseason': 'Did not make playoffs'},
#     '22.': {'team': 'Arizona Coyotes',
#      'gp': '56',
#      'w': '24',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '6',
#      'gf': '153',
#      'ga': '176',
#      'plus_minus': '-23',
#      'tp': '54',
#      'postseason': 'Did not make playoffs'},
#     '23.': {'team': 'Ottawa Senators',
#      'gp': '56',
#      'w': '23',
#      't': '-',
#      'l': '28',
#      'otw': '-',
#      'otl': '5',
#      'gf': '157',
#      'ga': '190',
#      'plus_minus': '-33',
#      'tp': '51',
#      'postseason': 'Did not make playoffs'},
#     '24.': {'team': 'Vancouver Canucks',
#      'gp': '55',
#      'w': '23',
#      't': '-',
#      'l': '29',
#      'otw': '-',
#      'otl': '4',
#      'gf': '149',
#      'ga': '182',
#      'plus_minus': '-33',
#      'tp': '50',
#      'postseason': 'Did not make playoffs'},
#     '25.': {'team': 'Los Angeles Kings',
#      'gp': '56',
#      'w': '21',
#      't': '-',
#      'l': '28',
#      'otw': '-',
#      'otl': '7',
#      'gf': '143',
#      'ga': '170',
#      'plus_minus': '-27',
#      'tp': '49',
#      'postseason': 'Did not make playoffs'},
#     '26.': {'team': 'San Jose Sharks',
#      'gp': '56',
#      'w': '21',
#      't': '-',
#      'l': '28',
#      'otw': '-',
#      'otl': '7',
#      'gf': '151',
#      'ga': '199',
#      'plus_minus': '-48',
#      'tp': '49',
#      'postseason': 'Did not make playoffs'},
#     '27.': {'team': 'Detroit Red Wings',
#      'gp': '56',
#      'w': '19',
#      't': '-',
#      'l': '27',
#      'otw': '-',
#      'otl': '10',
#      'gf': '127',
#      'ga': '171',
#      'plus_minus': '-44',
#      'tp': '48',
#      'postseason': 'Did not make playoffs'},
#     '28.': {'team': 'Columbus Blue Jackets',
#      'gp': '56',
#      'w': '18',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '12',
#      'gf': '137',
#      'ga': '187',
#      'plus_minus': '-50',
#      'tp': '48',
#      'postseason': 'Did not make playoffs'},
#     '29.': {'team': 'New Jersey Devils',
#      'gp': '56',
#      'w': '19',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '7',
#      'gf': '145',
#      'ga': '194',
#      'plus_minus': '-49',
#      'tp': '45',
#      'postseason': 'Did not make playoffs'},
#     '30.': {'team': 'Anaheim Ducks',
#      'gp': '56',
#      'w': '17',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '9',
#      'gf': '126',
#      'ga': '179',
#      'plus_minus': '-53',
#      'tp': '43',
#      'postseason': 'Did not make playoffs'},
#     '31.': {'team': 'Buffalo Sabres',
#      'gp': '56',
#      'w': '15',
#      't': '-',
#      'l': '34',
#      'otw': '-',
#      'otl': '7',
#      'gf': '138',
#      'ga': '199',
#      'plus_minus': '-61',
#      'tp': '37',
#      'postseason': 'Did not make playoffs'}}},
#   '2019-2020': {'main': {'1.': {'team': 'Boston Bruins',
#      'gp': '70',
#      'w': '44',
#      't': '-',
#      'l': '14',
#      'otw': '-',
#      'otl': '12',
#      'gf': '227',
#      'ga': '174',
#      'plus_minus': '53',
#      'tp': '100',
#      'postseason': 'Conference SF loss'},
#     '2.': {'team': 'St. Louis Blues',
#      'gp': '71',
#      'w': '42',
#      't': '-',
#      'l': '19',
#      'otw': '-',
#      'otl': '10',
#      'gf': '225',
#      'ga': '193',
#      'plus_minus': '32',
#      'tp': '94',
#      'postseason': 'Conference QF loss'},
#     '3.': {'team': 'Colorado Avalanche',
#      'gp': '70',
#      'w': '42',
#      't': '-',
#      'l': '20',
#      'otw': '-',
#      'otl': '8',
#      'gf': '237',
#      'ga': '191',
#      'plus_minus': '46',
#      'tp': '92',
#      'postseason': 'Conference SF loss'},
#     '4.': {'team': 'Tampa Bay Lightning',
#      'gp': '70',
#      'w': '43',
#      't': '-',
#      'l': '21',
#      'otw': '-',
#      'otl': '6',
#      'gf': '245',
#      'ga': '195',
#      'plus_minus': '50',
#      'tp': '92',
#      'postseason': 'Champion'},
#     '5.': {'team': 'Washington Capitals',
#      'gp': '69',
#      'w': '41',
#      't': '-',
#      'l': '20',
#      'otw': '-',
#      'otl': '8',
#      'gf': '240',
#      'ga': '215',
#      'plus_minus': '25',
#      'tp': '90',
#      'postseason': 'Conference QF loss'},
#     '6.': {'team': 'Philadelphia Flyers',
#      'gp': '69',
#      'w': '41',
#      't': '-',
#      'l': '21',
#      'otw': '-',
#      'otl': '7',
#      'gf': '232',
#      'ga': '196',
#      'plus_minus': '36',
#      'tp': '89',
#      'postseason': 'Conference SF loss'},
#     '7.': {'team': 'Pittsburgh Penguins',
#      'gp': '69',
#      'w': '40',
#      't': '-',
#      'l': '23',
#      'otw': '-',
#      'otl': '6',
#      'gf': '224',
#      'ga': '196',
#      'plus_minus': '28',
#      'tp': '86',
#      'postseason': 'Playoffs Qualifier loss'},
#     '8.': {'team': 'Vegas Golden Knights',
#      'gp': '71',
#      'w': '39',
#      't': '-',
#      'l': '24',
#      'otw': '-',
#      'otl': '8',
#      'gf': '227',
#      'ga': '211',
#      'plus_minus': '16',
#      'tp': '86',
#      'postseason': 'Conference Final loss'},
#     '9.': {'team': 'Carolina Hurricanes',
#      'gp': '68',
#      'w': '38',
#      't': '-',
#      'l': '25',
#      'otw': '-',
#      'otl': '5',
#      'gf': '222',
#      'ga': '193',
#      'plus_minus': '29',
#      'tp': '81',
#      'postseason': 'Conference QF loss'},
#     '10.': {'team': 'Dallas Stars',
#      'gp': '69',
#      'w': '37',
#      't': '-',
#      'l': '24',
#      'otw': '-',
#      'otl': '8',
#      'gf': '180',
#      'ga': '177',
#      'plus_minus': '3',
#      'tp': '82',
#      'postseason': 'Final loss'},
#     '11.': {'team': 'New York Islanders',
#      'gp': '68',
#      'w': '35',
#      't': '-',
#      'l': '23',
#      'otw': '-',
#      'otl': '10',
#      'gf': '192',
#      'ga': '193',
#      'plus_minus': '-1',
#      'tp': '80',
#      'postseason': 'Conference Final loss'},
#     '12.': {'team': 'Edmonton Oilers',
#      'gp': '71',
#      'w': '37',
#      't': '-',
#      'l': '25',
#      'otw': '-',
#      'otl': '9',
#      'gf': '225',
#      'ga': '217',
#      'plus_minus': '8',
#      'tp': '83',
#      'postseason': 'Playoffs Qualifier loss'},
#     '13.': {'team': 'Toronto Maple Leafs',
#      'gp': '70',
#      'w': '36',
#      't': '-',
#      'l': '25',
#      'otw': '-',
#      'otl': '9',
#      'gf': '238',
#      'ga': '227',
#      'plus_minus': '11',
#      'tp': '81',
#      'postseason': 'Playoffs Qualifier loss'},
#     '14.': {'team': 'Columbus Blue Jackets',
#      'gp': '70',
#      'w': '33',
#      't': '-',
#      'l': '22',
#      'otw': '-',
#      'otl': '15',
#      'gf': '180',
#      'ga': '187',
#      'plus_minus': '-7',
#      'tp': '81',
#      'postseason': 'Conference QF loss'},
#     '15.': {'team': 'Florida Panthers',
#      'gp': '69',
#      'w': '35',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '8',
#      'gf': '231',
#      'ga': '228',
#      'plus_minus': '3',
#      'tp': '78',
#      'postseason': 'Playoffs Qualifier loss'},
#     '16.': {'team': 'Nashville Predators',
#      'gp': '69',
#      'w': '35',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '8',
#      'gf': '215',
#      'ga': '217',
#      'plus_minus': '-2',
#      'tp': '78',
#      'postseason': 'Playoffs Qualifier loss'},
#     '17.': {'team': 'Vancouver Canucks',
#      'gp': '69',
#      'w': '36',
#      't': '-',
#      'l': '27',
#      'otw': '-',
#      'otl': '6',
#      'gf': '228',
#      'ga': '217',
#      'plus_minus': '11',
#      'tp': '78',
#      'postseason': 'Conference SF loss'},
#     '18.': {'team': 'New York Rangers',
#      'gp': '70',
#      'w': '37',
#      't': '-',
#      'l': '28',
#      'otw': '-',
#      'otl': '5',
#      'gf': '234',
#      'ga': '222',
#      'plus_minus': '12',
#      'tp': '79',
#      'postseason': 'Playoffs Qualifier loss'},
#     '19.': {'team': 'Calgary Flames',
#      'gp': '70',
#      'w': '36',
#      't': '-',
#      'l': '27',
#      'otw': '-',
#      'otl': '7',
#      'gf': '210',
#      'ga': '215',
#      'plus_minus': '-5',
#      'tp': '79',
#      'postseason': 'Conference QF loss'},
#     '20.': {'team': 'Winnipeg Jets',
#      'gp': '71',
#      'w': '37',
#      't': '-',
#      'l': '28',
#      'otw': '-',
#      'otl': '6',
#      'gf': '216',
#      'ga': '203',
#      'plus_minus': '13',
#      'tp': '80',
#      'postseason': 'Playoffs Qualifier loss'},
#     '21.': {'team': 'Minnesota Wild',
#      'gp': '69',
#      'w': '35',
#      't': '-',
#      'l': '27',
#      'otw': '-',
#      'otl': '7',
#      'gf': '220',
#      'ga': '220',
#      'plus_minus': '0',
#      'tp': '77',
#      'postseason': 'Playoffs Qualifier loss'},
#     '22.': {'team': 'Arizona Coyotes',
#      'gp': '70',
#      'w': '33',
#      't': '-',
#      'l': '29',
#      'otw': '-',
#      'otl': '8',
#      'gf': '195',
#      'ga': '187',
#      'plus_minus': '8',
#      'tp': '74',
#      'postseason': 'Conference QF loss'},
#     '23.': {'team': 'Chicago Blackhawks',
#      'gp': '70',
#      'w': '32',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '8',
#      'gf': '212',
#      'ga': '218',
#      'plus_minus': '-6',
#      'tp': '72',
#      'postseason': 'Conference QF loss'},
#     '24.': {'team': 'Montréal Canadiens',
#      'gp': '71',
#      'w': '31',
#      't': '-',
#      'l': '31',
#      'otw': '-',
#      'otl': '9',
#      'gf': '212',
#      'ga': '221',
#      'plus_minus': '-9',
#      'tp': '71',
#      'postseason': 'Conference QF loss'},
#     '25.': {'team': 'Buffalo Sabres',
#      'gp': '69',
#      'w': '30',
#      't': '-',
#      'l': '31',
#      'otw': '-',
#      'otl': '8',
#      'gf': '195',
#      'ga': '217',
#      'plus_minus': '-22',
#      'tp': '68',
#      'postseason': 'Did not make playoffs'},
#     '26.': {'team': 'New Jersey Devils',
#      'gp': '69',
#      'w': '28',
#      't': '-',
#      'l': '29',
#      'otw': '-',
#      'otl': '12',
#      'gf': '189',
#      'ga': '230',
#      'plus_minus': '-41',
#      'tp': '68',
#      'postseason': 'Did not make playoffs'},
#     '27.': {'team': 'Anaheim Ducks',
#      'gp': '71',
#      'w': '29',
#      't': '-',
#      'l': '33',
#      'otw': '-',
#      'otl': '9',
#      'gf': '187',
#      'ga': '226',
#      'plus_minus': '-39',
#      'tp': '67',
#      'postseason': 'Did not make playoffs'},
#     '28.': {'team': 'Los Angeles Kings',
#      'gp': '70',
#      'w': '29',
#      't': '-',
#      'l': '35',
#      'otw': '-',
#      'otl': '6',
#      'gf': '178',
#      'ga': '212',
#      'plus_minus': '-34',
#      'tp': '64',
#      'postseason': 'Did not make playoffs'},
#     '29.': {'team': 'San Jose Sharks',
#      'gp': '70',
#      'w': '29',
#      't': '-',
#      'l': '36',
#      'otw': '-',
#      'otl': '5',
#      'gf': '182',
#      'ga': '226',
#      'plus_minus': '-44',
#      'tp': '63',
#      'postseason': 'Did not make playoffs'},
#     '30.': {'team': 'Ottawa Senators',
#      'gp': '71',
#      'w': '25',
#      't': '-',
#      'l': '34',
#      'otw': '-',
#      'otl': '12',
#      'gf': '191',
#      'ga': '243',
#      'plus_minus': '-52',
#      'tp': '62',
#      'postseason': 'Did not make playoffs'},
#     '31.': {'team': 'Detroit Red Wings',
#      'gp': '71',
#      'w': '17',
#      't': '-',
#      'l': '49',
#      'otw': '-',
#      'otl': '5',
#      'gf': '145',
#      'ga': '267',
#      'plus_minus': '-122',
#      'tp': '39',
#      'postseason': 'Did not make playoffs'}}},
#   '2018-2019': {'main': {'1.': {'team': 'Tampa Bay Lightning',
#      'gp': '82',
#      'w': '62',
#      't': '-',
#      'l': '16',
#      'otw': '-',
#      'otl': '4',
#      'gf': '325',
#      'ga': '222',
#      'plus_minus': '103',
#      'tp': '128',
#      'postseason': 'Conference QF loss'},
#     '2.': {'team': 'Calgary Flames',
#      'gp': '82',
#      'w': '50',
#      't': '-',
#      'l': '25',
#      'otw': '-',
#      'otl': '7',
#      'gf': '289',
#      'ga': '227',
#      'plus_minus': '62',
#      'tp': '107',
#      'postseason': 'Conference QF loss'},
#     '3.': {'team': 'Boston Bruins',
#      'gp': '82',
#      'w': '49',
#      't': '-',
#      'l': '24',
#      'otw': '-',
#      'otl': '9',
#      'gf': '259',
#      'ga': '215',
#      'plus_minus': '44',
#      'tp': '107',
#      'postseason': 'Final loss'},
#     '4.': {'team': 'Washington Capitals',
#      'gp': '82',
#      'w': '48',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '8',
#      'gf': '278',
#      'ga': '249',
#      'plus_minus': '29',
#      'tp': '104',
#      'postseason': 'Conference QF loss'},
#     '5.': {'team': 'New York Islanders',
#      'gp': '82',
#      'w': '48',
#      't': '-',
#      'l': '27',
#      'otw': '-',
#      'otl': '7',
#      'gf': '228',
#      'ga': '196',
#      'plus_minus': '32',
#      'tp': '103',
#      'postseason': 'Conference SF loss'},
#     '6.': {'team': 'San Jose Sharks',
#      'gp': '82',
#      'w': '46',
#      't': '-',
#      'l': '27',
#      'otw': '-',
#      'otl': '9',
#      'gf': '289',
#      'ga': '261',
#      'plus_minus': '28',
#      'tp': '101',
#      'postseason': 'Conference Final loss'},
#     '7.': {'team': 'Toronto Maple Leafs',
#      'gp': '82',
#      'w': '46',
#      't': '-',
#      'l': '28',
#      'otw': '-',
#      'otl': '8',
#      'gf': '286',
#      'ga': '251',
#      'plus_minus': '35',
#      'tp': '100',
#      'postseason': 'Conference QF loss'},
#     '8.': {'team': 'Nashville Predators',
#      'gp': '82',
#      'w': '47',
#      't': '-',
#      'l': '29',
#      'otw': '-',
#      'otl': '6',
#      'gf': '240',
#      'ga': '214',
#      'plus_minus': '26',
#      'tp': '100',
#      'postseason': 'Conference QF loss'},
#     '9.': {'team': 'Pittsburgh Penguins',
#      'gp': '82',
#      'w': '44',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '12',
#      'gf': '273',
#      'ga': '241',
#      'plus_minus': '32',
#      'tp': '100',
#      'postseason': 'Conference QF loss'},
#     '10.': {'team': 'Winnipeg Jets',
#      'gp': '82',
#      'w': '47',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '5',
#      'gf': '272',
#      'ga': '244',
#      'plus_minus': '28',
#      'tp': '99',
#      'postseason': 'Conference QF loss'},
#     '11.': {'team': 'Carolina Hurricanes',
#      'gp': '82',
#      'w': '46',
#      't': '-',
#      'l': '29',
#      'otw': '-',
#      'otl': '7',
#      'gf': '245',
#      'ga': '223',
#      'plus_minus': '22',
#      'tp': '99',
#      'postseason': 'Conference Final loss'},
#     '12.': {'team': 'St. Louis Blues',
#      'gp': '82',
#      'w': '45',
#      't': '-',
#      'l': '28',
#      'otw': '-',
#      'otl': '9',
#      'gf': '247',
#      'ga': '223',
#      'plus_minus': '24',
#      'tp': '99',
#      'postseason': 'Champion'},
#     '13.': {'team': 'Columbus Blue Jackets',
#      'gp': '82',
#      'w': '47',
#      't': '-',
#      'l': '31',
#      'otw': '-',
#      'otl': '4',
#      'gf': '258',
#      'ga': '232',
#      'plus_minus': '26',
#      'tp': '98',
#      'postseason': 'Conference SF loss'},
#     '14.': {'team': 'Montréal Canadiens',
#      'gp': '82',
#      'w': '44',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '8',
#      'gf': '249',
#      'ga': '236',
#      'plus_minus': '13',
#      'tp': '96',
#      'postseason': 'Did not make playoffs'},
#     '15.': {'team': 'Dallas Stars',
#      'gp': '82',
#      'w': '43',
#      't': '-',
#      'l': '32',
#      'otw': '-',
#      'otl': '7',
#      'gf': '210',
#      'ga': '202',
#      'plus_minus': '8',
#      'tp': '93',
#      'postseason': 'Conference SF loss'},
#     '16.': {'team': 'Vegas Golden Knights',
#      'gp': '82',
#      'w': '43',
#      't': '-',
#      'l': '32',
#      'otw': '-',
#      'otl': '7',
#      'gf': '249',
#      'ga': '230',
#      'plus_minus': '19',
#      'tp': '93',
#      'postseason': 'Conference QF loss'},
#     '17.': {'team': 'Colorado Avalanche',
#      'gp': '82',
#      'w': '38',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '14',
#      'gf': '260',
#      'ga': '246',
#      'plus_minus': '14',
#      'tp': '90',
#      'postseason': 'Conference SF loss'},
#     '18.': {'team': 'Arizona Coyotes',
#      'gp': '82',
#      'w': '39',
#      't': '-',
#      'l': '35',
#      'otw': '-',
#      'otl': '8',
#      'gf': '213',
#      'ga': '223',
#      'plus_minus': '-10',
#      'tp': '86',
#      'postseason': 'Did not make playoffs'},
#     '19.': {'team': 'Florida Panthers',
#      'gp': '82',
#      'w': '36',
#      't': '-',
#      'l': '35',
#      'otw': '-',
#      'otl': '14',
#      'gf': '267',
#      'ga': '280',
#      'plus_minus': '-13',
#      'tp': '86',
#      'postseason': 'Did not make playoffs'},
#     '20.': {'team': 'Chicago Blackhawks',
#      'gp': '82',
#      'w': '36',
#      't': '-',
#      'l': '34',
#      'otw': '-',
#      'otl': '12',
#      'gf': '270',
#      'ga': '292',
#      'plus_minus': '-22',
#      'tp': '84',
#      'postseason': 'Did not make playoffs'},
#     '21.': {'team': 'Minnesota Wild',
#      'gp': '82',
#      'w': '37',
#      't': '-',
#      'l': '36',
#      'otw': '-',
#      'otl': '9',
#      'gf': '211',
#      'ga': '237',
#      'plus_minus': '-26',
#      'tp': '83',
#      'postseason': 'Did not make playoffs'},
#     '22.': {'team': 'Philadelphia Flyers',
#      'gp': '82',
#      'w': '37',
#      't': '-',
#      'l': '37',
#      'otw': '-',
#      'otl': '8',
#      'gf': '244',
#      'ga': '281',
#      'plus_minus': '-37',
#      'tp': '82',
#      'postseason': 'Did not make playoffs'},
#     '23.': {'team': 'Vancouver Canucks',
#      'gp': '82',
#      'w': '35',
#      't': '-',
#      'l': '36',
#      'otw': '-',
#      'otl': '11',
#      'gf': '225',
#      'ga': '254',
#      'plus_minus': '-29',
#      'tp': '81',
#      'postseason': 'Did not make playoffs'},
#     '24.': {'team': 'Anaheim Ducks',
#      'gp': '82',
#      'w': '35',
#      't': '-',
#      'l': '37',
#      'otw': '-',
#      'otl': '10',
#      'gf': '199',
#      'ga': '251',
#      'plus_minus': '-52',
#      'tp': '80',
#      'postseason': 'Did not make playoffs'},
#     '25.': {'team': 'Edmonton Oilers',
#      'gp': '82',
#      'w': '35',
#      't': '-',
#      'l': '38',
#      'otw': '-',
#      'otl': '9',
#      'gf': '232',
#      'ga': '274',
#      'plus_minus': '-42',
#      'tp': '79',
#      'postseason': 'Did not make playoffs'},
#     '26.': {'team': 'New York Rangers',
#      'gp': '82',
#      'w': '32',
#      't': '-',
#      'l': '36',
#      'otw': '-',
#      'otl': '14',
#      'gf': '227',
#      'ga': '272',
#      'plus_minus': '-45',
#      'tp': '78',
#      'postseason': 'Did not make playoffs'},
#     '27.': {'team': 'Buffalo Sabres',
#      'gp': '82',
#      'w': '33',
#      't': '-',
#      'l': '39',
#      'otw': '-',
#      'otl': '10',
#      'gf': '226',
#      'ga': '271',
#      'plus_minus': '-45',
#      'tp': '76',
#      'postseason': 'Did not make playoffs'},
#     '28.': {'team': 'Detroit Red Wings',
#      'gp': '82',
#      'w': '32',
#      't': '-',
#      'l': '40',
#      'otw': '-',
#      'otl': '10',
#      'gf': '227',
#      'ga': '277',
#      'plus_minus': '-50',
#      'tp': '74',
#      'postseason': 'Did not make playoffs'},
#     '29.': {'team': 'New Jersey Devils',
#      'gp': '82',
#      'w': '31',
#      't': '-',
#      'l': '41',
#      'otw': '-',
#      'otl': '10',
#      'gf': '222',
#      'ga': '275',
#      'plus_minus': '-53',
#      'tp': '72',
#      'postseason': 'Did not make playoffs'},
#     '30.': {'team': 'Los Angeles Kings',
#      'gp': '82',
#      'w': '31',
#      't': '-',
#      'l': '42',
#      'otw': '-',
#      'otl': '9',
#      'gf': '202',
#      'ga': '263',
#      'plus_minus': '-61',
#      'tp': '71',
#      'postseason': 'Did not make playoffs'},
#     '31.': {'team': 'Ottawa Senators',
#      'gp': '82',
#      'w': '29',
#      't': '-',
#      'l': '47',
#      'otw': '-',
#      'otl': '6',
#      'gf': '242',
#      'ga': '302',
#      'plus_minus': '-60',
#      'tp': '64',
#      'postseason': 'Did not make playoffs'}}},
#   '2017-2018': {'main': {'1.': {'team': 'Nashville Predators',
#      'gp': '82',
#      'w': '53',
#      't': '-',
#      'l': '18',
#      'otw': '-',
#      'otl': '11',
#      'gf': '267',
#      'ga': '211',
#      'plus_minus': '56',
#      'tp': '117',
#      'postseason': 'Conference SF loss'},
#     '2.': {'team': 'Winnipeg Jets',
#      'gp': '82',
#      'w': '52',
#      't': '-',
#      'l': '20',
#      'otw': '-',
#      'otl': '10',
#      'gf': '277',
#      'ga': '218',
#      'plus_minus': '59',
#      'tp': '114',
#      'postseason': 'Conference Final loss'},
#     '3.': {'team': 'Tampa Bay Lightning',
#      'gp': '82',
#      'w': '54',
#      't': '-',
#      'l': '23',
#      'otw': '-',
#      'otl': '5',
#      'gf': '296',
#      'ga': '236',
#      'plus_minus': '60',
#      'tp': '113',
#      'postseason': 'Conference Final loss'},
#     '4.': {'team': 'Boston Bruins',
#      'gp': '82',
#      'w': '50',
#      't': '-',
#      'l': '20',
#      'otw': '-',
#      'otl': '12',
#      'gf': '270',
#      'ga': '214',
#      'plus_minus': '56',
#      'tp': '112',
#      'postseason': 'Conference SF loss'},
#     '5.': {'team': 'Vegas Golden Knights',
#      'gp': '82',
#      'w': '51',
#      't': '-',
#      'l': '24',
#      'otw': '-',
#      'otl': '7',
#      'gf': '272',
#      'ga': '228',
#      'plus_minus': '44',
#      'tp': '109',
#      'postseason': 'Final loss'},
#     '6.': {'team': 'Washington Capitals',
#      'gp': '82',
#      'w': '49',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '7',
#      'gf': '259',
#      'ga': '239',
#      'plus_minus': '20',
#      'tp': '105',
#      'postseason': 'Champion'},
#     '7.': {'team': 'Toronto Maple Leafs',
#      'gp': '82',
#      'w': '49',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '7',
#      'gf': '277',
#      'ga': '232',
#      'plus_minus': '45',
#      'tp': '105',
#      'postseason': 'Conference QF loss'},
#     '8.': {'team': 'Minnesota Wild',
#      'gp': '82',
#      'w': '45',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '11',
#      'gf': '253',
#      'ga': '232',
#      'plus_minus': '21',
#      'tp': '101',
#      'postseason': 'Conference QF loss'},
#     '9.': {'team': 'Anaheim Ducks',
#      'gp': '82',
#      'w': '44',
#      't': '-',
#      'l': '25',
#      'otw': '-',
#      'otl': '13',
#      'gf': '235',
#      'ga': '216',
#      'plus_minus': '19',
#      'tp': '101',
#      'postseason': 'Conference QF loss'},
#     '10.': {'team': 'Pittsburgh Penguins',
#      'gp': '82',
#      'w': '47',
#      't': '-',
#      'l': '29',
#      'otw': '-',
#      'otl': '6',
#      'gf': '272',
#      'ga': '250',
#      'plus_minus': '22',
#      'tp': '100',
#      'postseason': 'Conference SF loss'},
#     '11.': {'team': 'San Jose Sharks',
#      'gp': '82',
#      'w': '45',
#      't': '-',
#      'l': '27',
#      'otw': '-',
#      'otl': '10',
#      'gf': '252',
#      'ga': '229',
#      'plus_minus': '23',
#      'tp': '100',
#      'postseason': 'Conference SF loss'},
#     '12.': {'team': 'Los Angeles Kings',
#      'gp': '82',
#      'w': '45',
#      't': '-',
#      'l': '29',
#      'otw': '-',
#      'otl': '8',
#      'gf': '239',
#      'ga': '203',
#      'plus_minus': '36',
#      'tp': '98',
#      'postseason': 'Conference QF loss'},
#     '13.': {'team': 'Philadelphia Flyers',
#      'gp': '82',
#      'w': '42',
#      't': '-',
#      'l': '26',
#      'otw': '-',
#      'otl': '14',
#      'gf': '251',
#      'ga': '243',
#      'plus_minus': '8',
#      'tp': '98',
#      'postseason': 'Conference QF loss'},
#     '14.': {'team': 'Columbus Blue Jackets',
#      'gp': '82',
#      'w': '45',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '7',
#      'gf': '242',
#      'ga': '230',
#      'plus_minus': '12',
#      'tp': '97',
#      'postseason': 'Conference QF loss'},
#     '15.': {'team': 'New Jersey Devils',
#      'gp': '82',
#      'w': '44',
#      't': '-',
#      'l': '29',
#      'otw': '-',
#      'otl': '9',
#      'gf': '248',
#      'ga': '244',
#      'plus_minus': '4',
#      'tp': '97',
#      'postseason': 'Conference QF loss'},
#     '16.': {'team': 'Florida Panthers',
#      'gp': '82',
#      'w': '44',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '8',
#      'gf': '248',
#      'ga': '246',
#      'plus_minus': '2',
#      'tp': '96',
#      'postseason': 'Did not make playoffs'},
#     '17.': {'team': 'Colorado Avalanche',
#      'gp': '82',
#      'w': '43',
#      't': '-',
#      'l': '30',
#      'otw': '-',
#      'otl': '9',
#      'gf': '257',
#      'ga': '237',
#      'plus_minus': '20',
#      'tp': '95',
#      'postseason': 'Conference QF loss'},
#     '18.': {'team': 'St. Louis Blues',
#      'gp': '82',
#      'w': '44',
#      't': '-',
#      'l': '32',
#      'otw': '-',
#      'otl': '6',
#      'gf': '226',
#      'ga': '222',
#      'plus_minus': '4',
#      'tp': '94',
#      'postseason': 'Did not make playoffs'},
#     '19.': {'team': 'Dallas Stars',
#      'gp': '82',
#      'w': '42',
#      't': '-',
#      'l': '32',
#      'otw': '-',
#      'otl': '8',
#      'gf': '235',
#      'ga': '225',
#      'plus_minus': '10',
#      'tp': '92',
# ...
#      'otw': '-',
#      'otl': '-',
#      'gf': '72',
#      'ga': '63',
#      'plus_minus': '9',
#      'tp': '47',
#      'postseason': 'Quarterfinal loss'},
#     '7.': {'team': 'Ottawa HC (Senators)',
#      'gp': '44',
#      'w': '14',
#      't': '13',
#      'l': '17',
#      'otw': '-',
#      'otl': '-',
#      'gf': '54',
#      'ga': '67',
#      'plus_minus': '-13',
#      'tp': '41',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Montréal Maroons',
#      'gp': '44',
#      'w': '15',
#      't': '9',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '67',
#      'ga': '65',
#      'plus_minus': '2',
#      'tp': '39',
#      'postseason': 'Did not make playoffs'},
#     '9.': {'team': 'Pittsburgh Pirates',
#      'gp': '44',
#      'w': '9',
#      't': '8',
#      'l': '27',
#      'otw': '-',
#      'otl': '-',
#      'gf': '46',
#      'ga': '80',
#      'plus_minus': '-34',
#      'tp': '26',
#      'postseason': 'Did not make playoffs'},
#     '10.': {'team': 'Chicago Black Hawks',
#      'gp': '44',
#      'w': '7',
#      't': '8',
#      'l': '29',
#      'otw': '-',
#      'otl': '-',
#      'gf': '33',
#      'ga': '85',
#      'plus_minus': '-52',
#      'tp': '22',
#      'postseason': 'Did not make playoffs'}}},
#   '1927-1928': {'main': {'1.': {'team': 'Montréal Canadiens',
#      'gp': '44',
#      'w': '26',
#      't': '7',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '116',
#      'ga': '48',
#      'plus_minus': '68',
#      'tp': '59',
#      'postseason': 'Semifinal loss'},
#     '2.': {'team': 'Montréal Maroons',
#      'gp': '44',
#      'w': '24',
#      't': '6',
#      'l': '14',
#      'otw': '-',
#      'otl': '-',
#      'gf': '96',
#      'ga': '77',
#      'plus_minus': '19',
#      'tp': '54',
#      'postseason': 'Final loss'},
#     '3.': {'team': 'Boston Bruins',
#      'gp': '44',
#      'w': '20',
#      't': '11',
#      'l': '13',
#      'otw': '-',
#      'otl': '-',
#      'gf': '77',
#      'ga': '70',
#      'plus_minus': '7',
#      'tp': '51',
#      'postseason': 'Semifinal loss'},
#     '4.': {'team': 'Ottawa HC (Senators)',
#      'gp': '44',
#      'w': '20',
#      't': '10',
#      'l': '14',
#      'otw': '-',
#      'otl': '-',
#      'gf': '78',
#      'ga': '57',
#      'plus_minus': '21',
#      'tp': '50',
#      'postseason': 'Quarterfinal loss'},
#     '5.': {'team': 'New York Rangers',
#      'gp': '44',
#      'w': '19',
#      't': '9',
#      'l': '16',
#      'otw': '-',
#      'otl': '-',
#      'gf': '94',
#      'ga': '79',
#      'plus_minus': '15',
#      'tp': '47',
#      'postseason': 'Champion'},
#     '6.': {'team': 'Pittsburgh Pirates',
#      'gp': '44',
#      'w': '19',
#      't': '8',
#      'l': '17',
#      'otw': '-',
#      'otl': '-',
#      'gf': '67',
#      'ga': '76',
#      'plus_minus': '-9',
#      'tp': '46',
#      'postseason': 'Quarterfinal loss'},
#     '7.': {'team': 'Detroit Cougars',
#      'gp': '44',
#      'w': '19',
#      't': '6',
#      'l': '19',
#      'otw': '-',
#      'otl': '-',
#      'gf': '88',
#      'ga': '79',
#      'plus_minus': '9',
#      'tp': '44',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Toronto Maple Leafs',
#      'gp': '44',
#      'w': '18',
#      't': '8',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '89',
#      'ga': '88',
#      'plus_minus': '1',
#      'tp': '44',
#      'postseason': 'Did not make playoffs'},
#     '9.': {'team': 'New York Americans',
#      'gp': '44',
#      'w': '11',
#      't': '6',
#      'l': '27',
#      'otw': '-',
#      'otl': '-',
#      'gf': '63',
#      'ga': '128',
#      'plus_minus': '-65',
#      'tp': '28',
#      'postseason': 'Did not make playoffs'},
#     '10.': {'team': 'Chicago Black Hawks',
#      'gp': '44',
#      'w': '7',
#      't': '3',
#      'l': '34',
#      'otw': '-',
#      'otl': '-',
#      'gf': '68',
#      'ga': '134',
#      'plus_minus': '-66',
#      'tp': '17',
#      'postseason': 'Did not make playoffs'}}},
#   '1926-1927': {'main': {'1.': {'team': 'Ottawa HC (Senators)',
#      'gp': '44',
#      'w': '30',
#      't': '4',
#      'l': '10',
#      'otw': '-',
#      'otl': '-',
#      'gf': '86',
#      'ga': '69',
#      'plus_minus': '17',
#      'tp': '64',
#      'postseason': 'Champion'},
#     '2.': {'team': 'Montréal Canadiens',
#      'gp': '44',
#      'w': '28',
#      't': '2',
#      'l': '14',
#      'otw': '-',
#      'otl': '-',
#      'gf': '99',
#      'ga': '67',
#      'plus_minus': '32',
#      'tp': '58',
#      'postseason': 'Semifinal loss'},
#     '3.': {'team': 'New York Rangers',
#      'gp': '44',
#      'w': '25',
#      't': '6',
#      'l': '13',
#      'otw': '-',
#      'otl': '-',
#      'gf': '95',
#      'ga': '72',
#      'plus_minus': '23',
#      'tp': '56',
#      'postseason': 'Semifinal loss'},
#     '4.': {'team': 'Boston Bruins',
#      'gp': '44',
#      'w': '21',
#      't': '3',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '97',
#      'ga': '89',
#      'plus_minus': '8',
#      'tp': '45',
#      'postseason': 'Final loss'},
#     '5.': {'team': 'Montréal Maroons',
#      'gp': '44',
#      'w': '20',
#      't': '4',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '71',
#      'ga': '68',
#      'plus_minus': '3',
#      'tp': '44',
#      'postseason': 'Quarterfinal loss'},
#     '6.': {'team': 'Chicago Black Hawks',
#      'gp': '44',
#      'w': '19',
#      't': '3',
#      'l': '22',
#      'otw': '-',
#      'otl': '-',
#      'gf': '115',
#      'ga': '116',
#      'plus_minus': '-1',
#      'tp': '41',
#      'postseason': 'Quarterfinal loss'},
#     '7.': {'team': 'New York Americans',
#      'gp': '44',
#      'w': '17',
#      't': '2',
#      'l': '25',
#      'otw': '-',
#      'otl': '-',
#      'gf': '82',
#      'ga': '91',
#      'plus_minus': '-9',
#      'tp': '36',
#      'postseason': 'Did not make playoffs'},
#     '8.': {'team': 'Toronto St. Patricks/Maple Leafs',
#      'gp': '44',
#      'w': '15',
#      't': '5',
#      'l': '24',
#      'otw': '-',
#      'otl': '-',
#      'gf': '79',
#      'ga': '94',
#      'plus_minus': '-15',
#      'tp': '35',
#      'postseason': 'Did not make playoffs'},
#     '9.': {'team': 'Pittsburgh Pirates',
#      'gp': '44',
#      'w': '15',
#      't': '3',
#      'l': '26',
#      'otw': '-',
#      'otl': '-',
#      'gf': '79',
#      'ga': '108',
#      'plus_minus': '-29',
#      'tp': '33',
#      'postseason': 'Did not make playoffs'},
#     '10.': {'team': 'Detroit Cougars',
#      'gp': '44',
#      'w': '12',
#      't': '4',
#      'l': '28',
#      'otw': '-',
#      'otl': '-',
#      'gf': '76',
#      'ga': '105',
#      'plus_minus': '-29',
#      'tp': '28',
#      'postseason': 'Did not make playoffs'}}},
#   '1925-1926': {'main': {'1.': {'team': 'Ottawa HC (Senators)',
#      'gp': '36',
#      'w': '24',
#      't': '4',
#      'l': '8',
#      'otw': '-',
#      'otl': '-',
#      'gf': '77',
#      'ga': '42',
#      'plus_minus': '35',
#      'tp': '52',
#      'postseason': 'Final group'},
#     '2.': {'team': 'Montréal Maroons',
#      'gp': '36',
#      'w': '20',
#      't': '5',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '91',
#      'ga': '73',
#      'plus_minus': '18',
#      'tp': '45',
#      'postseason': 'Champion'},
#     '3.': {'team': 'Pittsburgh Pirates',
#      'gp': '36',
#      'w': '19',
#      't': '1',
#      'l': '16',
#      'otw': '-',
#      'otl': '-',
#      'gf': '82',
#      'ga': '70',
#      'plus_minus': '12',
#      'tp': '39',
#      'postseason': 'Semifinal loss'},
#     '4.': {'team': 'Boston Bruins',
#      'gp': '36',
#      'w': '17',
#      't': '4',
#      'l': '15',
#      'otw': '-',
#      'otl': '-',
#      'gf': '92',
#      'ga': '85',
#      'plus_minus': '7',
#      'tp': '38',
#      'postseason': 'Did not make playoffs'},
#     '5.': {'team': 'New York Americans',
#      'gp': '36',
#      'w': '12',
#      't': '4',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '68',
#      'ga': '89',
#      'plus_minus': '-21',
#      'tp': '28',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'Toronto St. Patricks',
#      'gp': '36',
#      'w': '12',
#      't': '3',
#      'l': '21',
#      'otw': '-',
#      'otl': '-',
#      'gf': '92',
#      'ga': '114',
#      'plus_minus': '-22',
#      'tp': '27',
#      'postseason': 'Did not make playoffs'},
#     '7.': {'team': 'Montréal Canadiens',
#      'gp': '36',
#      'w': '11',
#      't': '1',
#      'l': '24',
#      'otw': '-',
#      'otl': '-',
#      'gf': '79',
#      'ga': '108',
#      'plus_minus': '-29',
#      'tp': '23',
#      'postseason': 'Did not make playoffs'}}},
#   '1924-1925': {'main': {'1.': {'team': 'Hamilton Tigers',
#      'gp': '30',
#      'w': '19',
#      't': '1',
#      'l': '10',
#      'otw': '-',
#      'otl': '-',
#      'gf': '90',
#      'ga': '60',
#      'plus_minus': '30',
#      'tp': '39',
#      'postseason': 'Did not make playoffs'},
#     '2.': {'team': 'Toronto St. Patricks',
#      'gp': '30',
#      'w': '19',
#      't': '0',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '90',
#      'ga': '84',
#      'plus_minus': '6',
#      'tp': '38',
#      'postseason': 'Final loss'},
#     '3.': {'team': 'Montréal Canadiens',
#      'gp': '30',
#      'w': '17',
#      't': '2',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '93',
#      'ga': '56',
#      'plus_minus': '37',
#      'tp': '36',
#      'postseason': 'Champion'},
#     '4.': {'team': 'Ottawa HC (Senators)',
#      'gp': '30',
#      'w': '17',
#      't': '1',
#      'l': '12',
#      'otw': '-',
#      'otl': '-',
#      'gf': '83',
#      'ga': '66',
#      'plus_minus': '17',
#      'tp': '35',
#      'postseason': 'Did not make playoffs'},
#     '5.': {'team': 'Montréal Maroons',
#      'gp': '30',
#      'w': '9',
#      't': '2',
#      'l': '19',
#      'otw': '-',
#      'otl': '-',
#      'gf': '45',
#      'ga': '65',
#      'plus_minus': '-20',
#      'tp': '20',
#      'postseason': 'Did not make playoffs'},
#     '6.': {'team': 'Boston Bruins',
#      'gp': '30',
#      'w': '6',
#      't': '0',
#      'l': '24',
#      'otw': '-',
#      'otl': '-',
#      'gf': '49',
#      'ga': '119',
#      'plus_minus': '-70',
#      'tp': '12',
#      'postseason': 'Did not make playoffs'}}},
#   '1923-1924': {'main': {'1.': {'team': 'Ottawa HC (Senators)',
#      'gp': '24',
#      'w': '16',
#      't': '0',
#      'l': '8',
#      'otw': '-',
#      'otl': '-',
#      'gf': '74',
#      'ga': '54',
#      'plus_minus': '20',
#      'tp': '32',
#      'postseason': 'Final loss'},
#     '2.': {'team': 'Montréal Canadiens',
#      'gp': '24',
#      'w': '13',
#      't': '0',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '59',
#      'ga': '48',
#      'plus_minus': '11',
#      'tp': '26',
#      'postseason': 'Champion'},
#     '3.': {'team': 'Toronto St. Patricks',
#      'gp': '24',
#      'w': '10',
#      't': '0',
#      'l': '14',
#      'otw': '-',
#      'otl': '-',
#      'gf': '59',
#      'ga': '85',
#      'plus_minus': '-26',
#      'tp': '20',
#      'postseason': 'Did not make playoffs'},
#     '4.': {'team': 'Hamilton Tigers',
#      'gp': '24',
#      'w': '9',
#      't': '0',
#      'l': '15',
#      'otw': '-',
#      'otl': '-',
#      'gf': '63',
#      'ga': '68',
#      'plus_minus': '-5',
#      'tp': '18',
#      'postseason': 'Did not make playoffs'}}},
#   '1922-1923': {'main': {'1.': {'team': 'Ottawa HC (Senators)',
#      'gp': '24',
#      'w': '14',
#      't': '1',
#      'l': '9',
#      'otw': '-',
#      'otl': '-',
#      'gf': '77',
#      'ga': '54',
#      'plus_minus': '23',
#      'tp': '29',
#      'postseason': 'Champion'},
#     '2.': {'team': 'Montréal Canadiens',
#      'gp': '24',
#      'w': '13',
#      't': '2',
#      'l': '9',
#      'otw': '-',
#      'otl': '-',
#      'gf': '73',
#      'ga': '61',
#      'plus_minus': '12',
#      'tp': '28',
#      'postseason': 'Final loss'},
#     '3.': {'team': 'Toronto St. Patricks',
#      'gp': '24',
#      'w': '13',
#      't': '1',
#      'l': '10',
#      'otw': '-',
#      'otl': '-',
#      'gf': '82',
#      'ga': '88',
#      'plus_minus': '-6',
#      'tp': '27',
#      'postseason': 'Did not make playoffs'},
#     '4.': {'team': 'Hamilton Tigers',
#      'gp': '24',
#      'w': '6',
#      't': '0',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '81',
#      'ga': '110',
#      'plus_minus': '-29',
#      'tp': '12',
#      'postseason': 'Did not make playoffs'}}},
#   '1921-1922': {'main': {'1.': {'team': 'Ottawa HC (Senators)',
#      'gp': '24',
#      'w': '14',
#      't': '2',
#      'l': '8',
#      'otw': '-',
#      'otl': '-',
#      'gf': '106',
#      'ga': '84',
#      'plus_minus': '22',
#      'tp': '30',
#      'postseason': 'Final loss'},
#     '2.': {'team': 'Toronto St. Patricks',
#      'gp': '24',
#      'w': '13',
#      't': '1',
#      'l': '10',
#      'otw': '-',
#      'otl': '-',
#      'gf': '98',
#      'ga': '97',
#      'plus_minus': '1',
#      'tp': '27',
#      'postseason': 'Champion'},
#     '3.': {'team': 'Montréal Canadiens',
#      'gp': '24',
#      'w': '12',
#      't': '1',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '88',
#      'ga': '94',
#      'plus_minus': '-6',
#      'tp': '25',
#      'postseason': 'Did not make playoffs'},
#     '4.': {'team': 'Hamilton Tigers',
#      'gp': '24',
#      'w': '7',
#      't': '0',
#      'l': '17',
#      'otw': '-',
#      'otl': '-',
#      'gf': '88',
#      'ga': '105',
#      'plus_minus': '-17',
#      'tp': '14',
#      'postseason': 'Did not make playoffs'}}},
#   '1920-1921': {'main': {'1.': {'team': 'Toronto St. Patricks',
#      'gp': '24',
#      'w': '15',
#      't': '0',
#      'l': '9',
#      'otw': '-',
#      'otl': '-',
#      'gf': '105',
#      'ga': '100',
#      'plus_minus': '5',
#      'tp': '30',
#      'postseason': 'Final loss'},
#     '2.': {'team': 'Ottawa HC (Senators)',
#      'gp': '24',
#      'w': '14',
#      't': '0',
#      'l': '10',
#      'otw': '-',
#      'otl': '-',
#      'gf': '97',
#      'ga': '75',
#      'plus_minus': '22',
#      'tp': '28',
#      'postseason': 'Champion'},
#     '3.': {'team': 'Montréal Canadiens',
#      'gp': '24',
#      'w': '13',
#      't': '0',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '112',
#      'ga': '99',
#      'plus_minus': '13',
#      'tp': '26',
#      'postseason': 'Did not make playoffs'},
#     '4.': {'team': 'Hamilton Tigers',
#      'gp': '24',
#      'w': '6',
#      't': '0',
#      'l': '18',
#      'otw': '-',
#      'otl': '-',
#      'gf': '92',
#      'ga': '132',
#      'plus_minus': '-40',
#      'tp': '12',
#      'postseason': 'Did not make playoffs'}}},
#   '1919-1920': {'main': {'1.': {'team': 'Ottawa HC (Senators)',
#      'gp': '24',
#      'w': '19',
#      't': '0',
#      'l': '5',
#      'otw': '-',
#      'otl': '-',
#      'gf': '121',
#      'ga': '64',
#      'plus_minus': '57',
#      'tp': '38',
#      'postseason': 'Champion'},
#     '2.': {'team': 'Montréal Canadiens',
#      'gp': '24',
#      'w': '13',
#      't': '0',
#      'l': '11',
#      'otw': '-',
#      'otl': '-',
#      'gf': '129',
#      'ga': '113',
#      'plus_minus': '16',
#      'tp': '26',
#      'postseason': 'Did not make playoffs'},
#     '3.': {'team': 'Toronto St. Patricks',
#      'gp': '24',
#      'w': '12',
#      't': '0',
#      'l': '12',
#      'otw': '-',
#      'otl': '-',
#      'gf': '119',
#      'ga': '106',
#      'plus_minus': '13',
#      'tp': '24',
#      'postseason': 'Did not make playoffs'},
#     '4.': {'team': 'Québec Athletic Club',
#      'gp': '24',
#      'w': '4',
#      't': '0',
#      'l': '20',
#      'otw': '-',
#      'otl': '-',
#      'gf': '91',
#      'ga': '177',
#      'plus_minus': '-86',
#      'tp': '8',
#      'postseason': 'Did not make playoffs'}}},
#   '1917-1918': {'main': {'1.': {'team': 'Montréal Canadiens',
#      'gp': '22',
#      'w': '13',
#      't': '0',
#      'l': '9',
#      'otw': '-',
#      'otl': '-',
#      'gf': '115',
#      'ga': '84',
#      'plus_minus': '31',
#      'tp': '26',
#      'postseason': 'Final loss'},
#     '2.': {'team': 'Toronto Hockey Club',
#      'gp': '22',
#      'w': '13',
#      't': '0',
#      'l': '9',
#      'otw': '-',
#      'otl': '-',
#      'gf': '108',
#      'ga': '109',
#      'plus_minus': '-1',
#      'tp': '26',
#      'postseason': 'Champion'},
#     '3.': {'team': 'Ottawa HC (Senators)',
#      'gp': '22',
#      'w': '9',
#      't': '0',
#      'l': '13',
#      'otw': '-',
#      'otl': '-',
#      'gf': '102',
#      'ga': '114',
#      'plus_minus': '-12',
#      'tp': '18',
#      'postseason': 'Did not make playoffs'},
#     '4.': {'team': 'Montréal Wanderers',
#      'gp': '6',
#      'w': '1',
#      't': '0',
#      'l': '5',
#      'otw': '-',
#      'otl': '-',
#      'gf': '17',
#      'ga': '35',
#      'plus_minus': '-18',
#      'tp': '2',
#      'postseason': 'Did not make playoffs'}}}}}

# %%
import src.project_elite.update_dict.wraper as update_wraper
lu_o = update_wraper.UpdateDictWraper()
league_data_2 = lu_o.update_league_dict(league_data)
# Out:
# Eastern/Atlantic Division
# Eastern/Metropolitan Division
# Western/Central Division
# Western/Pacific Division
# Atlantic Division
# Central Division
# Metropolitan Division
# Pacific Division
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main
# main

# %% [markdown]
# ## Team

# %% [markdown]
# ### Team Scraper

# %%
import scraper.team.team as team_scraper
ts_o = team_scraper.TeamScraper("https://www.eliteprospects.com/team/8303/bk-havlickuv-brod-u16")
team_data = ts_o.get_info()
team_data
# Out:
# [1, 9, 13]
# 1
# 2
# {'general_info': {' Plays in ': '',
#   ' Full name ': 'BK Havlíčkův Brod - dorostenci',
#   ' Town ': 'Havlickuv Brod, CZE',
#   ' Founded ': '2009',
#   'short_name': 'BK Havlickuv Brod U16',
#   'u_id': 8303},
#  'stadium_info': {'Construction Year': '1957',
#   'Capacity': '4 000',
#   'Location': 'Havlickuv Brod',
#   'Arena Name': 'Kotlina'},
#  'affiliated_teams': ['https://www.eliteprospects.com/team/2469/bk-havlickuv-brod'],
#  'retired_numbers': {},
#  'titles': {'HC Havlickuv Brod U16': {'min': '2009-2010', 'max': '2014-2015'},
#   'BK Havlickuv Brod U16': {'min': '2015-2016', 'max': '2018-2019'}}}

# %% [markdown]
# ### Team Update

# %%
import update_dict.sections.team_info as team_updater
tu_o = team_updater.UpdateTeamDict()
team_dict_updated = tu_o.update_team_dict_wrap(team_data)
team_dict_updated
# Out:
# {'general_info': {' Plays in ': '', ' Full name ': 'BK Havlíčkův Brod - dorostenci', ' Town ': 'Havlickuv Brod, CZE', ' Founded ': '2009', 'short_name': 'BK Havlickuv Brod U16', 'u_id': 8303}, 'stadium_info': {'Construction Year': '1957', 'Capacity': '4 000', 'Location': 'Havlickuv Brod', 'Arena Name': 'Kotlina'}, 'affiliated_teams': ['https://www.eliteprospects.com/team/2469/bk-havlickuv-brod'], 'retired_numbers': {}, 'titles': {'HC Havlickuv Brod U16': {'min': '2009-2010', 'max': '2014-2015'}, 'BK Havlickuv Brod U16': {'min': '2015-2016', 'max': '2018-2019'}}}
# https://www.eliteprospects.com/team/2469/bk-havlickuv-brod
# {'general_info': {'short_name': 'BK Havlickuv Brod U16', 'u_id': 8303, 'plays_in': '', 'full_name': 'BK Havlíčkův Brod - dorostenci', 'town': 'Havlickuv Brod, CZE', 'founded': '2009', 'place': {'place': 'Havlickuv Brod', 'country': 'CZE', 'region': None}}, 'stadium_info': {'construction_year': '1957', 'capacity': '4 000', 'location': 'Havlickuv Brod', 'arena_name': 'Kotlina', 'place': {'country': None, 'region': None, 'place': None}}, 'affiliated_teams': {'2469': 'https://www.eliteprospects.com/team/2469/bk-havlickuv-brod'}, 'retired_numbers': {}, 'titles': {'HC Havlickuv Brod U16': {'min': '2009-2010', 'max': '2014-2015'}, 'BK Havlickuv Brod U16': {'min': '2015-2016', 'max': '2018-2019'}}}
# {'general_info': {'short_name': 'BK Havlickuv Brod U16', 'u_id': 8303, 'plays_in': '', 'full_name': 'BK Havlíčkův Brod - dorostenci', 'town': 'Havlickuv Brod, CZE', 'founded': 2009, 'place': {'place': 'Havlickuv Brod', 'country': 'CZE', 'region': None}}, 'stadium_info': {'construction_year': 1957, 'capacity': 4000, 'location': 'Havlickuv Brod', 'arena_name': 'Kotlina', 'place': {'country': None, 'region': None, 'place': None}}, 'affiliated_teams': {'2469': 'https://www.eliteprospects.com/team/2469/bk-havlickuv-brod'}, 'retired_numbers': {}, 'titles': {'HC Havlickuv Brod U16': {'min': '2009-2010', 'max': '2014-2015'}, 'BK Havlickuv Brod U16': {'min': '2015-2016', 'max': '2018-2019'}}}
# {'general_info': {'short_name': 'BK Havlickuv Brod U16', 'u_id': 8303, 'plays_in': '', 'full_name': 'BK Havlíčkův Brod - dorostenci', 'town': 'Havlickuv Brod, CZE', 'founded': 2009, 'place': {'place': 'Havlickuv Brod', 'country': 'CZE', 'region': None}, 'active': 1}, 'stadium_info': {'construction_year': 1957, 'capacity': 4000, 'location': 'Havlickuv Brod', 'arena_name': 'Kotlina', 'place': {'country': None, 'region': None, 'place': None}}, 'affiliated_teams': {'2469': 'https://www.eliteprospects.com/team/2469/bk-havlickuv-brod'}, 'retired_numbers': {}, 'titles': {'HC Havlickuv Brod U16': {'min': '2009-2010', 'max': '2014-2015'}, 'BK Havlickuv Brod U16': {'min': '2015-2016', 'max': '2018-2019'}}}
# {'general_info': {'short_name': 'BK Havlickuv Brod U16',
#   'u_id': 8303,
#   'plays_in': '',
#   'full_name': 'BK Havlíčkův Brod - dorostenci',
#   'founded': 2009,
#   'place': {'place': 'Havlickuv Brod', 'country': 'CZE', 'region': None},
#   'active': 1,
#   'team_colours': None},
#  'stadium_info': {'construction_year': 1957,
#   'capacity': 4000,
#   'arena_name': 'Kotlina',
#   'place': {'country': None, 'region': None, 'place': None}},
#  'affiliated_teams': {'2469': 'https://www.eliteprospects.com/team/2469/bk-havlickuv-brod'},
#  'retired_numbers': {},
#  'titles': {'HC Havlickuv Brod U16': {'min': '2009-2010', 'max': '2014-2015'},
#   'BK Havlickuv Brod U16': {'min': '2015-2016', 'max': '2018-2019'}}}

# %% [markdown]
# ### Team Insert

# %%
import database.entry_data.input_dict as input_dict_2
insert_team_data = input_dict_2.InputTeamDict()
insert_team_data.input_team_dict(team_dict=team_dict_updated)
# Out:
# {'short_name': 'BK Havlickuv Brod U16', 'u_id': 8303, 'plays_in': '', 'full_name': 'BK Havlíčkův Brod - dorostenci', 'founded': 2009, 'place': {'place': 'Havlickuv Brod', 'country': 'CZE', 'region': None}, 'active': 1, 'team_colours': None}
# {'construction_year': 1957, 'capacity': 4000, 'arena_name': 'Kotlina', 'place': {'country': None, 'region': None, 'place': None}}
# None

# %%
import database.entry_data.input_dict as input_dict
inset_team_data = input_dict.InputTeamDict()
insert_team_data.input_team_dict(team_dict=team_dict_updated)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import database.entry_data.input_dict as input_dict
#       2 inset_team_data = input_dict.InputTeamDict()
# ----> 3 insert_team_data.input_team_dict(team_dict=team_dict_updated)
#
# NameError: name 'insert_team_data' is not defined

# %%
import database.entry_data.input_dict as input_dict
inset_team_data = input_dict.InputTeamDict()
insert_team_data.input_team_dict(team_dict=team_dict_updated)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import database.entry_data.input_dict as input_dict
#       2 inset_team_data = input_dict.InputTeamDict()
# ----> 3 insert_team_data.input_team_dict(team_dict=team_dict_updated)
#
# NameError: name 'insert_team_data' is not defined

# %%
import src.project_elite.scraper.player.player as player_scraper
ps_o = player_scraper.PlayerScraper(url="https://www.eliteprospects.com/player/300436/nick-suzuki")
dict_gi = ps_o.get_info_all()
dict_gi
# Out:
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Date of Birth')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Age')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Place of Birth')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Nation')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Position')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Height')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Weight')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Shoots')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Contract')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Cap Hit')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'NHL Rights')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Drafted')]]//text()
# //div[contains(@class, 'ep-list__item--is-compact')]/div[preceding-sibling::div[contains(text(), 'Status')]]//text()
# ['\n                                                            ', '\n                                                                                    Nick Suzuki\n                                                    ']
# https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa/2013-2014?tab=stats
# https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa
# https://www.eliteprospects.com/league/alliance-u15/stats/2013-2014
# https://www.eliteprospects.com/league/alliance-u15
# {'ALLIANCE U15': {'London Jr. Knights U15 AAA': {'regular_season': ['-', '-', '-', '-', '-', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa'}, 'url': 'https://www.eliteprospects.com/league/alliance-u15'}}
# https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa/2014-2015?tab=stats
# https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa
# https://www.eliteprospects.com/league/alliance-u16/stats/2014-2015
# https://www.eliteprospects.com/league/alliance-u16
# {'ALLIANCE U16': {'London Jr. Knights U16 AAA': {'regular_season': ['31', '34', '34', '68', '16', '-'], 'play_off': ['13', '4', '5', '9', '10', '-'], 'url': 'https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa'}, 'url': 'https://www.eliteprospects.com/league/alliance-u16'}}
# https://www.eliteprospects.com/team/2136/london-nationals/2014-2015?tab=stats
# https://www.eliteprospects.com/team/2136/london-nationals
# https://www.eliteprospects.com/league/gojhl/stats/2014-2015
# https://www.eliteprospects.com/league/gojhl
# {'GOJHL': {'London Nationals': {'regular_season': ['1', '0', '1', '1', '0', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/2136/london-nationals'}, 'url': 'https://www.eliteprospects.com/league/gojhl'}}
# https://www.eliteprospects.com/team/874/owen-sound-attack/2015-2016?tab=stats
# https://www.eliteprospects.com/team/874/owen-sound-attack
# https://www.eliteprospects.com/league/ohl/stats/2015-2016
# https://www.eliteprospects.com/league/ohl
# {'OHL': {'Owen Sound Attack': {'regular_season': ['63', '20', '18', '38', '4', '-15'], 'play_off': ['6', '2', '0', '2', '0', '-6'], 'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack'}, 'url': 'https://www.eliteprospects.com/league/ohl'}}
# https://www.eliteprospects.com/team/16277/canada-white-u17/2015-2016?tab=stats
# https://www.eliteprospects.com/team/16277/canada-white-u17
# https://www.eliteprospects.com/league/whc-17/stats/2015-2016
# https://www.eliteprospects.com/league/whc-17
# {'WHC-17': {'Canada White U17': {'regular_season': ['6', '1', '3', '4', '2', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/16277/canada-white-u17'}, 'url': 'https://www.eliteprospects.com/league/whc-17'}}
# https://www.eliteprospects.com/team/874/owen-sound-attack/2016-2017?tab=stats
# https://www.eliteprospects.com/team/874/owen-sound-attack
# https://www.eliteprospects.com/league/ohl/stats/2016-2017
# https://www.eliteprospects.com/league/ohl
# {'OHL': {'Owen Sound Attack': {'regular_season': ['65', '45', '51', '96', '10', '51'], 'play_off': ['17', '8', '15', '23', '10', '7'], 'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack'}, 'url': 'https://www.eliteprospects.com/league/ohl'}}
# https://www.eliteprospects.com/team/874/owen-sound-attack/2017-2018?tab=stats
# https://www.eliteprospects.com/team/874/owen-sound-attack
# https://www.eliteprospects.com/league/ohl/stats/2017-2018
# https://www.eliteprospects.com/league/ohl
# {'OHL': {'Owen Sound Attack': {'regular_season': ['64', '42', '58', '100', '18', '30'], 'play_off': ['11', '3', '9', '12', '2', '-4'], 'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack', 'leadership': '“A”'}, 'url': 'https://www.eliteprospects.com/league/ohl'}}
# https://www.eliteprospects.com/team/94/chicago-wolves/2017-2018?tab=stats
# https://www.eliteprospects.com/team/94/chicago-wolves
# https://www.eliteprospects.com/league/ahl/stats/2017-2018
# https://www.eliteprospects.com/league/ahl
# {'AHL': {'Chicago Wolves': {'regular_season': ['0', '0', '0', '0', '0', '0'], 'play_off': ['1', '0', '0', '0', '0', '0'], 'url': 'https://www.eliteprospects.com/team/94/chicago-wolves'}, 'url': 'https://www.eliteprospects.com/league/ahl'}}
# https://www.eliteprospects.com/team/874/owen-sound-attack/2018-2019?tab=stats
# https://www.eliteprospects.com/team/874/owen-sound-attack
# https://www.eliteprospects.com/league/ohl/stats/2018-2019
# https://www.eliteprospects.com/league/ohl
# {'OHL': {'Owen Sound Attack': {'regular_season': ['30', '22', '23', '45', '4', '12'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack', 'leadership': '“C”'}, 'url': 'https://www.eliteprospects.com/league/ohl'}}
# https://www.eliteprospects.com/team/552/guelph-storm/2018-2019?tab=stats
# https://www.eliteprospects.com/team/552/guelph-storm
# https://www.eliteprospects.com/league/ohl/stats/2018-2019
# https://www.eliteprospects.com/league/ohl
# {'OHL': {'Guelph Storm': {'regular_season': ['29', '12', '37', '49', '8', '28'], 'play_off': ['24', '16', '26', '42', '16', '22'], 'url': 'https://www.eliteprospects.com/team/552/guelph-storm'}, 'url': 'https://www.eliteprospects.com/league/ohl'}}
# https://www.eliteprospects.com/team/1618/canada-u20/2018-2019?tab=stats
# https://www.eliteprospects.com/team/1618/canada-u20
# https://www.eliteprospects.com/league/wjc-20/stats/2018-2019
# https://www.eliteprospects.com/league/wjc-20
# {'WJC-20': {'Canada U20': {'regular_season': ['5', '0', '3', '3', '4', '3'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/1618/canada-u20'}, 'url': 'https://www.eliteprospects.com/league/wjc-20'}}
# https://www.eliteprospects.com/team/64/montreal-canadiens/2019-2020?tab=stats
# https://www.eliteprospects.com/team/64/montreal-canadiens
# https://www.eliteprospects.com/league/nhl/stats/2019-2020
# https://www.eliteprospects.com/league/nhl
# {'NHL': {'Montréal Canadiens': {'regular_season': ['71', '13', '28', '41', '6', '-15'], 'play_off': ['10', '4', '3', '7', '0', '3'], 'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens'}, 'url': 'https://www.eliteprospects.com/league/nhl'}}
# https://www.eliteprospects.com/team/64/montreal-canadiens/2020-2021?tab=stats
# https://www.eliteprospects.com/team/64/montreal-canadiens
# https://www.eliteprospects.com/league/nhl/stats/2020-2021
# https://www.eliteprospects.com/league/nhl
# {'NHL': {'Montréal Canadiens': {'regular_season': ['56', '15', '26', '41', '26', '-5'], 'play_off': ['22', '7', '9', '16', '2', '-6'], 'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens'}, 'url': 'https://www.eliteprospects.com/league/nhl'}}
# https://www.eliteprospects.com/team/64/montreal-canadiens/2021-2022?tab=stats
# https://www.eliteprospects.com/team/64/montreal-canadiens
# https://www.eliteprospects.com/league/nhl/stats/2021-2022
# https://www.eliteprospects.com/league/nhl
# {'NHL': {'Montréal Canadiens': {'regular_season': ['82', '21', '40', '61', '30', '-29'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens', 'leadership': '“A”'}, 'url': 'https://www.eliteprospects.com/league/nhl'}}
# https://www.eliteprospects.com/team/64/montreal-canadiens/2022-2023?tab=stats
# https://www.eliteprospects.com/team/64/montreal-canadiens
# https://www.eliteprospects.com/league/nhl/stats/2022-2023
# https://www.eliteprospects.com/league/nhl
# {'NHL': {'Montréal Canadiens': {'regular_season': ['82', '26', '40', '66', '33', '-13'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens', 'leadership': '“C”'}, 'url': 'https://www.eliteprospects.com/league/nhl'}}
# https://www.eliteprospects.com/team/64/montreal-canadiens/2023-2024?tab=stats
# https://www.eliteprospects.com/team/64/montreal-canadiens
# https://www.eliteprospects.com/league/nhl/stats/2023-2024
# https://www.eliteprospects.com/league/nhl
# {'NHL': {'Montréal Canadiens': {'regular_season': ['-', '-', '-', '-', '-', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens', 'leadership': '“C”'}, 'url': 'https://www.eliteprospects.com/league/nhl'}}
# https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa/2013-2014?tab=stats
# https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa
# https://www.eliteprospects.com/league/ohf-bantam-aaa/stats/2013-2014
# https://www.eliteprospects.com/league/ohf-bantam-aaa
# {'OHF Bantam AAA': {'London Jr. Knights U15 AAA': {'regular_season': ['8', '6', '2', '8', '2', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa'}, 'url': 'https://www.eliteprospects.com/league/ohf-bantam-aaa'}}
# https://www.eliteprospects.com/team/9308/team-ontario/2014-2015?tab=stats
# https://www.eliteprospects.com/team/9308/team-ontario
# https://www.eliteprospects.com/league/cwg/stats/2014-2015
# https://www.eliteprospects.com/league/cwg
# {'CWG': {'Team Ontario': {'regular_season': ['6', '3', '1', '4', '0', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/9308/team-ontario'}, 'url': 'https://www.eliteprospects.com/league/cwg'}}
# https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa/2014-2015?tab=stats
# https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa
# https://www.eliteprospects.com/league/ohl-cup/stats/2014-2015
# https://www.eliteprospects.com/league/ohl-cup
# {'OHL Cup': {'London Jr. Knights U16 AAA': {'regular_season': ['6', '2', '4', '6', '2', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa'}, 'url': 'https://www.eliteprospects.com/league/ohl-cup'}}
# https://www.eliteprospects.com/team/15260/team-alliance/2014-2015?tab=stats
# https://www.eliteprospects.com/team/15260/team-alliance
# https://www.eliteprospects.com/league/ogc-16/stats/2014-2015
# https://www.eliteprospects.com/league/ogc-16
# {'OGC-16': {'Team ALLIANCE': {'regular_season': ['5', '3', '3', '6', '0', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/15260/team-alliance'}, 'url': 'https://www.eliteprospects.com/league/ogc-16'}}
# https://www.eliteprospects.com/team/17644/team-white/2015-2016?tab=stats
# https://www.eliteprospects.com/team/17644/team-white
# https://www.eliteprospects.com/league/u17-dev/stats/2015-2016
# https://www.eliteprospects.com/league/u17-dev
# {'U17-Dev': {'Team White': {'regular_season': ['3', '0', '2', '2', '2', '-'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/17644/team-white'}, 'url': 'https://www.eliteprospects.com/league/u17-dev'}}
# https://www.eliteprospects.com/team/14443/canada-u18/2016-2017?tab=stats
# https://www.eliteprospects.com/team/14443/canada-u18
# https://www.eliteprospects.com/league/ivan-hlinka-memorial/stats/2016-2017
# https://www.eliteprospects.com/league/ivan-hlinka-memorial
# {'Ivan Hlinka Memorial': {'Canada U18': {'regular_season': ['4', '1', '2', '3', '0', '1'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/14443/canada-u18'}, 'url': 'https://www.eliteprospects.com/league/ivan-hlinka-memorial'}}
# https://www.eliteprospects.com/team/16795/ohl-all-stars/2017-2018?tab=stats
# https://www.eliteprospects.com/team/16795/ohl-all-stars
# https://www.eliteprospects.com/league/jr-super-series/stats/2017-2018
# https://www.eliteprospects.com/league/jr-super-series
# {'Jr Super Series': {'OHL All-Stars': {'regular_season': ['2', '2', '1', '3', '0', '0'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/16795/ohl-all-stars', 'leadership': '“A”'}, 'url': 'https://www.eliteprospects.com/league/jr-super-series'}}
# https://www.eliteprospects.com/team/552/guelph-storm/2018-2019?tab=stats
# https://www.eliteprospects.com/team/552/guelph-storm
# https://www.eliteprospects.com/league/m-cup/stats/2018-2019
# https://www.eliteprospects.com/league/m-cup
# {'M-Cup': {'Guelph Storm': {'regular_season': ['4', '3', '4', '7', '0', '3'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/552/guelph-storm'}, 'url': 'https://www.eliteprospects.com/league/m-cup'}}
# https://www.eliteprospects.com/team/16795/ohl-all-stars/2018-2019?tab=stats
# https://www.eliteprospects.com/team/16795/ohl-all-stars
# https://www.eliteprospects.com/league/jr-super-series/stats/2018-2019
# https://www.eliteprospects.com/league/jr-super-series
# {'Jr Super Series': {'OHL All-Stars': {'regular_season': ['1', '0', '0', '0', '0', '0'], 'play_off': ['', '', '', '', '', ''], 'url': 'https://www.eliteprospects.com/team/16795/ohl-all-stars', 'leadership': '“C”'}, 'url': 'https://www.eliteprospects.com/league/jr-super-series'}}
# c:\Users\jziac\miniforge3\envs\p-env\lib\site-packages\scrapy\selector\unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
# {'info': {'Date of Birth': 'Aug 10, 1999',
#   'Age': '23',
#   'Place of Birth': 'London, ON, CAN',
#   'Nation': 'Canada',
#   'Position': 'C',
#   'Height': '180 cm / 5\'11"',
#   'Weight': '93 kg / 205 lbs',
#   'Shoots': 'R',
#   'Contract': '29/30',
#   'Cap Hit': '$7,875,000',
#   'NHL Rights': 'Montréal Canadiens / Signed',
#   'Drafted': ['2017 round 1 #13 overall by Vegas Golden Knights'],
#   'Status': None,
#   'name': 'Nick Suzuki'},
#  'achievements': {'2011-2012': [' AHPPL Champion '],
#   '2012-2013': [' AHMBPL Champion '],
#   '2013-2014': [' ALLIANCE U15 Champion '],
#   '2014-2015': [' ALLIANCE Hockey Player of the Year ',
#    ' ALLIANCE U16 Most Goals ',
#    ' ALLIANCE U16 Most Points ',
#    ' CWG Champion ',
#    ' OHL Gold Cup Silver Medal '],
#   '2015-2016': [' OHL First All-Rookie Team ',
#    ' U17 Dev Camp Tournament Champion ',
#    ' U17 WHC Gold Medal '],
#   '2016-2017': [' CHL Sportsman of the Year ',
#    ' OHL Most Sportsmanlike Player (William Hanley Trophy) ',
#    ' OHL Second All-Star Team '],
#   '2017-2018': [' OHL Most Sportsmanlike Player (William Hanley Trophy) '],
#   '2018-2019': [' CHL Memorial Cup Most Sportsmanlike Player ',
#    ' OHL Champion ',
#    ' OHL Most Sportsmanlike Player (William Hanley Trophy) ',
#    ' OHL Playoffs Most Assists ',
#    ' OHL Playoffs Most Points ',
#    ' OHL Playoffs MVP (Wayne Gretzky 99 Award) ',
#    ' OHL Third All-Star Team '],
#   '2019-2020': [' NHL All-Rookie Team '],
#   '2021-2022': [' NHL All-Star Game '],
#   '2022-2023': [' NHL All-Star Game ']},
#  'stats': {'leagues': {'2013-2014': {'ALLIANCE U15': {'London Jr. Knights U15 AAA': {'regular_season': ['-',
#        '-',
#        '-',
#        '-',
#        '-',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa'},
#      'url': 'https://www.eliteprospects.com/league/alliance-u15'}},
#    '2014-2015': {'ALLIANCE U16': {'London Jr. Knights U16 AAA': {'regular_season': ['31',
#        '34',
#        '34',
#        '68',
#        '16',
#        '-'],
#       'play_off': ['13', '4', '5', '9', '10', '-'],
#       'url': 'https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa'},
#      'url': 'https://www.eliteprospects.com/league/alliance-u16'},
#     'GOJHL': {'London Nationals': {'regular_season': ['1',
#        '0',
#        '1',
#        '1',
#        '0',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/2136/london-nationals'},
#      'url': 'https://www.eliteprospects.com/league/gojhl'}},
#    '2015-2016': {'OHL': {'Owen Sound Attack': {'regular_season': ['63',
#        '20',
#        '18',
#        '38',
#        '4',
#        '-15'],
#       'play_off': ['6', '2', '0', '2', '0', '-6'],
#       'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack'},
#      'url': 'https://www.eliteprospects.com/league/ohl'},
#     'WHC-17': {'Canada White U17': {'regular_season': ['6',
#        '1',
#        '3',
#        '4',
#        '2',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/16277/canada-white-u17'},
#      'url': 'https://www.eliteprospects.com/league/whc-17'}},
#    '2016-2017': {'OHL': {'Owen Sound Attack': {'regular_season': ['65',
#        '45',
#        '51',
#        '96',
#        '10',
#        '51'],
#       'play_off': ['17', '8', '15', '23', '10', '7'],
#       'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack'},
#      'url': 'https://www.eliteprospects.com/league/ohl'}},
#    '2017-2018': {'OHL': {'Owen Sound Attack': {'regular_season': ['64',
#        '42',
#        '58',
#        '100',
#        '18',
#        '30'],
#       'play_off': ['11', '3', '9', '12', '2', '-4'],
#       'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack',
#       'leadership': '“A”'},
#      'url': 'https://www.eliteprospects.com/league/ohl'},
#     'AHL': {'Chicago Wolves': {'regular_season': ['0',
#        '0',
#        '0',
#        '0',
#        '0',
#        '0'],
#       'play_off': ['1', '0', '0', '0', '0', '0'],
#       'url': 'https://www.eliteprospects.com/team/94/chicago-wolves'},
#      'url': 'https://www.eliteprospects.com/league/ahl'}},
#    '2018-2019': {'OHL': {'Guelph Storm': {'regular_season': ['29',
#        '12',
#        '37',
#        '49',
#        '8',
#        '28'],
#       'play_off': ['24', '16', '26', '42', '16', '22'],
#       'url': 'https://www.eliteprospects.com/team/552/guelph-storm'},
#      'url': 'https://www.eliteprospects.com/league/ohl'},
#     'WJC-20': {'Canada U20': {'regular_season': ['5', '0', '3', '3', '4', '3'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/1618/canada-u20'},
#      'url': 'https://www.eliteprospects.com/league/wjc-20'}},
#    '2019-2020': {'NHL': {'Montréal Canadiens': {'regular_season': ['71',
#        '13',
#        '28',
#        '41',
#        '6',
#        '-15'],
#       'play_off': ['10', '4', '3', '7', '0', '3'],
#       'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens'},
#      'url': 'https://www.eliteprospects.com/league/nhl'}},
#    '2020-2021': {'NHL': {'Montréal Canadiens': {'regular_season': ['56',
#        '15',
#        '26',
#        '41',
#        '26',
#        '-5'],
#       'play_off': ['22', '7', '9', '16', '2', '-6'],
#       'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens'},
#      'url': 'https://www.eliteprospects.com/league/nhl'}},
#    '2021-2022': {'NHL': {'Montréal Canadiens': {'regular_season': ['82',
#        '21',
#        '40',
#        '61',
#        '30',
#        '-29'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens',
#       'leadership': '“A”'},
#      'url': 'https://www.eliteprospects.com/league/nhl'}},
#    '2022-2023': {'NHL': {'Montréal Canadiens': {'regular_season': ['82',
#        '26',
#        '40',
#        '66',
#        '33',
#        '-13'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens',
#       'leadership': '“C”'},
#      'url': 'https://www.eliteprospects.com/league/nhl'}},
#    '2023-2024': {'NHL': {'Montréal Canadiens': {'regular_season': ['-',
#        '-',
#        '-',
#        '-',
#        '-',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens',
#       'leadership': '“C”'},
#      'url': 'https://www.eliteprospects.com/league/nhl'}}},
#   'tournaments': {'2013-2014': {'OHF Bantam AAA': {'London Jr. Knights U15 AAA': {'regular_season': ['8',
#        '6',
#        '2',
#        '8',
#        '2',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa'},
#      'url': 'https://www.eliteprospects.com/league/ohf-bantam-aaa'}},
#    '2014-2015': {'CWG': {'Team Ontario': {'regular_season': ['6',
#        '3',
#        '1',
#        '4',
#        '0',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/9308/team-ontario'},
#      'url': 'https://www.eliteprospects.com/league/cwg'},
#     'OHL Cup': {'London Jr. Knights U16 AAA': {'regular_season': ['6',
#        '2',
#        '4',
#        '6',
#        '2',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa'},
#      'url': 'https://www.eliteprospects.com/league/ohl-cup'},
#     'OGC-16': {'Team ALLIANCE': {'regular_season': ['5',
#        '3',
#        '3',
#        '6',
#        '0',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/15260/team-alliance'},
#      'url': 'https://www.eliteprospects.com/league/ogc-16'}},
#    '2015-2016': {'U17-Dev': {'Team White': {'regular_season': ['3',
#        '0',
#        '2',
#        '2',
#        '2',
#        '-'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/17644/team-white'},
#      'url': 'https://www.eliteprospects.com/league/u17-dev'}},
#    '2016-2017': {'Ivan Hlinka Memorial': {'Canada U18': {'regular_season': ['4',
#        '1',
#        '2',
#        '3',
#        '0',
#        '1'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/14443/canada-u18'},
#      'url': 'https://www.eliteprospects.com/league/ivan-hlinka-memorial'}},
#    '2017-2018': {'Jr Super Series': {'OHL All-Stars': {'regular_season': ['2',
#        '2',
#        '1',
#        '3',
#        '0',
#        '0'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/16795/ohl-all-stars',
#       'leadership': '“A”'},
#      'url': 'https://www.eliteprospects.com/league/jr-super-series'}},
#    '2018-2019': {'M-Cup': {'Guelph Storm': {'regular_season': ['4',
#        '3',
#        '4',
#        '7',
#        '0',
#        '3'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/552/guelph-storm'},
#      'url': 'https://www.eliteprospects.com/league/m-cup'},
#     'Jr Super Series': {'OHL All-Stars': {'regular_season': ['1',
#        '0',
#        '0',
#        '0',
#        '0',
#        '0'],
#       'play_off': ['', '', '', '', '', ''],
#       'url': 'https://www.eliteprospects.com/team/16795/ohl-all-stars',
#       'leadership': '“C”'},
#      'url': 'https://www.eliteprospects.com/league/jr-super-series'}}}},
#  'u_id': '300436'}

# %%
import src.project_elite.update_dict.sections.player_info as player_update
up_o = player_update.UpdatePlayerInfo(is_goalie=False)
dict_player_info_updated = up_o.update_info_wraper(dict_gi["info"])
# Out:
# 23
# Active
# orig_date:
# Aug 10, 1999

# %%
dict_player_info_updated
# Out:
# {'age': 23,
#  'nation': 'Canada',
#  'position': 'C',
#  'height': 180,
#  'weight': 93,
#  'shoots': 'R',
#  'contract': '29/30',
#  'cap_hit': 7875000,
#  'drafted': True,
#  'name': 'Nick Suzuki',
#  'active': True,
#  'draft_info': {0: {'draft_year': 2017,
#    'draft_round': 1,
#    'draft_position': 13,
#    'draft_team': 'Vegas Golden Knights',
#    'team_uid': '22211'}},
#  'birth_place': 'London',
#  'birth_country': 'CAN',
#  'birth_region': 'ON',
#  'date_birth': datetime.date(1999, 8, 10),
#  'nhl_team_rights': 'Montréal Canadiens',
#  'team_uid': '64',
#  'signed_nhl': True,
#  'catches': None}

# %%
import src.project_elite.update_dict.sections.player_stats as player_stats_update
ps_u = player_stats_update.UpdatePlayerStats(is_goalie=False)
dict_stats_updated = ps_u.update_stats_dict(dict_stats=dict_gi["stats"])
dict_stats_updated
# Out:
# {'leagues': {'2013-2014': {'ALLIANCE U15': {'London Jr. Knights U15 AAA': {'regular_season': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa',
#      'team_id': ['13793']},
#     'url': 'https://www.eliteprospects.com/league/alliance-u15',
#     'league_id': 'alliance-u15'}},
#   '2014-2015': {'ALLIANCE U16': {'London Jr. Knights U16 AAA': {'regular_season': {'gp': 31,
#       'g': 34,
#       'a': 34,
#       'tp': 68,
#       'PIM': 16,
#       'plus_minus': None},
#      'play_off': {'gp': 13,
#       'g': 4,
#       'a': 5,
#       'tp': 9,
#       'PIM': 10,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa',
#      'team_id': ['16025']},
#     'url': 'https://www.eliteprospects.com/league/alliance-u16',
#     'league_id': 'alliance-u16'},
#    'GOJHL': {'London Nationals': {'regular_season': {'gp': 1,
#       'g': 0,
#       'a': 1,
#       'tp': 1,
#       'PIM': 0,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/2136/london-nationals',
#      'team_id': ['2136']},
#     'url': 'https://www.eliteprospects.com/league/gojhl',
#     'league_id': 'gojhl'}},
#   '2015-2016': {'OHL': {'Owen Sound Attack': {'regular_season': {'gp': 63,
#       'g': 20,
#       'a': 18,
#       'tp': 38,
#       'PIM': 4,
#       'plus_minus': -15},
#      'play_off': {'gp': 6,
#       'g': 2,
#       'a': 0,
#       'tp': 2,
#       'PIM': 0,
#       'plus_minus': -6},
#      'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack',
#      'team_id': ['874']},
#     'url': 'https://www.eliteprospects.com/league/ohl',
#     'league_id': 'ohl'},
#    'WHC-17': {'Canada White U17': {'regular_season': {'gp': 6,
#       'g': 1,
#       'a': 3,
#       'tp': 4,
#       'PIM': 2,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/16277/canada-white-u17',
#      'team_id': ['16277']},
#     'url': 'https://www.eliteprospects.com/league/whc-17',
#     'league_id': 'whc-17'}},
#   '2016-2017': {'OHL': {'Owen Sound Attack': {'regular_season': {'gp': 65,
#       'g': 45,
#       'a': 51,
#       'tp': 96,
#       'PIM': 10,
#       'plus_minus': 51},
#      'play_off': {'gp': 17,
#       'g': 8,
#       'a': 15,
#       'tp': 23,
#       'PIM': 10,
#       'plus_minus': 7},
#      'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack',
#      'team_id': ['874']},
#     'url': 'https://www.eliteprospects.com/league/ohl',
#     'league_id': 'ohl'}},
#   '2017-2018': {'OHL': {'Owen Sound Attack': {'regular_season': {'gp': 64,
#       'g': 42,
#       'a': 58,
#       'tp': 100,
#       'PIM': 18,
#       'plus_minus': 30},
#      'play_off': {'gp': 11,
#       'g': 3,
#       'a': 9,
#       'tp': 12,
#       'PIM': 2,
#       'plus_minus': -4},
#      'url': 'https://www.eliteprospects.com/team/874/owen-sound-attack',
#      'leadership': 'A',
#      'team_id': ['874']},
#     'url': 'https://www.eliteprospects.com/league/ohl',
#     'league_id': 'ohl'},
#    'AHL': {'Chicago Wolves': {'regular_season': {'gp': 0,
#       'g': 0,
#       'a': 0,
#       'tp': 0,
#       'PIM': 0,
#       'plus_minus': 0},
#      'play_off': {'gp': 1, 'g': 0, 'a': 0, 'tp': 0, 'PIM': 0, 'plus_minus': 0},
#      'url': 'https://www.eliteprospects.com/team/94/chicago-wolves',
#      'team_id': ['94']},
#     'url': 'https://www.eliteprospects.com/league/ahl',
#     'league_id': 'ahl'}},
#   '2018-2019': {'OHL': {'Guelph Storm': {'regular_season': {'gp': 29,
#       'g': 12,
#       'a': 37,
#       'tp': 49,
#       'PIM': 8,
#       'plus_minus': 28},
#      'play_off': {'gp': 24,
#       'g': 16,
#       'a': 26,
#       'tp': 42,
#       'PIM': 16,
#       'plus_minus': 22},
#      'url': 'https://www.eliteprospects.com/team/552/guelph-storm',
#      'team_id': ['552']},
#     'url': 'https://www.eliteprospects.com/league/ohl',
#     'league_id': 'ohl'},
#    'WJC-20': {'Canada U20': {'regular_season': {'gp': 5,
#       'g': 0,
#       'a': 3,
#       'tp': 3,
#       'PIM': 4,
#       'plus_minus': 3},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/1618/canada-u20',
#      'team_id': ['1618']},
#     'url': 'https://www.eliteprospects.com/league/wjc-20',
#     'league_id': 'wjc-20'}},
#   '2019-2020': {'NHL': {'Montréal Canadiens': {'regular_season': {'gp': 71,
#       'g': 13,
#       'a': 28,
#       'tp': 41,
#       'PIM': 6,
#       'plus_minus': -15},
#      'play_off': {'gp': 10,
#       'g': 4,
#       'a': 3,
#       'tp': 7,
#       'PIM': 0,
#       'plus_minus': 3},
#      'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens',
#      'team_id': ['64']},
#     'url': 'https://www.eliteprospects.com/league/nhl',
#     'league_id': 'nhl'}},
#   '2020-2021': {'NHL': {'Montréal Canadiens': {'regular_season': {'gp': 56,
#       'g': 15,
#       'a': 26,
#       'tp': 41,
#       'PIM': 26,
#       'plus_minus': -5},
#      'play_off': {'gp': 22,
#       'g': 7,
#       'a': 9,
#       'tp': 16,
#       'PIM': 2,
#       'plus_minus': -6},
#      'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens',
#      'team_id': ['64']},
#     'url': 'https://www.eliteprospects.com/league/nhl',
#     'league_id': 'nhl'}},
#   '2021-2022': {'NHL': {'Montréal Canadiens': {'regular_season': {'gp': 82,
#       'g': 21,
#       'a': 40,
#       'tp': 61,
#       'PIM': 30,
#       'plus_minus': -29},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens',
#      'leadership': 'A',
#      'team_id': ['64']},
#     'url': 'https://www.eliteprospects.com/league/nhl',
#     'league_id': 'nhl'}},
#   '2022-2023': {'NHL': {'Montréal Canadiens': {'regular_season': {'gp': 82,
#       'g': 26,
#       'a': 40,
#       'tp': 66,
#       'PIM': 33,
#       'plus_minus': -13},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens',
#      'leadership': 'C',
#      'team_id': ['64']},
#     'url': 'https://www.eliteprospects.com/league/nhl',
#     'league_id': 'nhl'}},
#   '2023-2024': {'NHL': {'Montréal Canadiens': {'regular_season': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/64/montreal-canadiens',
#      'leadership': 'C',
#      'team_id': ['64']},
#     'url': 'https://www.eliteprospects.com/league/nhl',
#     'league_id': 'nhl'}}},
#  'tournaments': {'2013-2014': {'OHF Bantam AAA': {'London Jr. Knights U15 AAA': {'regular_season': {'gp': 8,
#       'g': 6,
#       'a': 2,
#       'tp': 8,
#       'PIM': 2,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/13793/london-jr.-knights-u15-aaa',
#      'team_id': ['13793']},
#     'url': 'https://www.eliteprospects.com/league/ohf-bantam-aaa',
#     'league_id': 'ohf-bantam-aaa'}},
#   '2014-2015': {'CWG': {'Team Ontario': {'regular_season': {'gp': 6,
#       'g': 3,
#       'a': 1,
#       'tp': 4,
#       'PIM': 0,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/9308/team-ontario',
#      'team_id': ['9308']},
#     'url': 'https://www.eliteprospects.com/league/cwg',
#     'league_id': 'cwg'},
#    'OHL Cup': {'London Jr. Knights U16 AAA': {'regular_season': {'gp': 6,
#       'g': 2,
#       'a': 4,
#       'tp': 6,
#       'PIM': 2,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/16025/london-jr.-knights-u16-aaa',
#      'team_id': ['16025']},
#     'url': 'https://www.eliteprospects.com/league/ohl-cup',
#     'league_id': 'ohl-cup'},
#    'OGC-16': {'Team ALLIANCE': {'regular_season': {'gp': 5,
#       'g': 3,
#       'a': 3,
#       'tp': 6,
#       'PIM': 0,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/15260/team-alliance',
#      'team_id': ['15260']},
#     'url': 'https://www.eliteprospects.com/league/ogc-16',
#     'league_id': 'ogc-16'}},
#   '2015-2016': {'U17-Dev': {'Team White': {'regular_season': {'gp': 3,
#       'g': 0,
#       'a': 2,
#       'tp': 2,
#       'PIM': 2,
#       'plus_minus': None},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/17644/team-white',
#      'team_id': ['17644']},
#     'url': 'https://www.eliteprospects.com/league/u17-dev',
#     'league_id': 'u17-dev'}},
#   '2016-2017': {'Ivan Hlinka Memorial': {'Canada U18': {'regular_season': {'gp': 4,
#       'g': 1,
#       'a': 2,
#       'tp': 3,
#       'PIM': 0,
#       'plus_minus': 1},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/14443/canada-u18',
#      'team_id': ['14443']},
#     'url': 'https://www.eliteprospects.com/league/ivan-hlinka-memorial',
#     'league_id': 'ivan-hlinka-memorial'}},
#   '2017-2018': {'Jr Super Series': {'OHL All-Stars': {'regular_season': {'gp': 2,
#       'g': 2,
#       'a': 1,
#       'tp': 3,
#       'PIM': 0,
#       'plus_minus': 0},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/16795/ohl-all-stars',
#      'leadership': 'A',
#      'team_id': ['16795']},
#     'url': 'https://www.eliteprospects.com/league/jr-super-series',
#     'league_id': 'jr-super-series'}},
#   '2018-2019': {'M-Cup': {'Guelph Storm': {'regular_season': {'gp': 4,
#       'g': 3,
#       'a': 4,
#       'tp': 7,
#       'PIM': 0,
#       'plus_minus': 3},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/552/guelph-storm',
#      'team_id': ['552']},
#     'url': 'https://www.eliteprospects.com/league/m-cup',
#     'league_id': 'm-cup'},
#    'Jr Super Series': {'OHL All-Stars': {'regular_season': {'gp': 1,
#       'g': 0,
#       'a': 0,
#       'tp': 0,
#       'PIM': 0,
#       'plus_minus': 0},
#      'play_off': {'gp': None,
#       'g': None,
#       'a': None,
#       'tp': None,
#       'PIM': None,
#       'plus_minus': None},
#      'url': 'https://www.eliteprospects.com/team/16795/ohl-all-stars',
#      'leadership': 'C',
#      'team_id': ['16795']},
#     'url': 'https://www.eliteprospects.com/league/jr-super-series',
#     'league_id': 'jr-super-series'}}}}

# %%
dict_stats_updated
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dict_stats_updated["stadium_info"]
#
# KeyError: 'stadium_info'
